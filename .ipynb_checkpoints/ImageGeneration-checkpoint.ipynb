# %%
import torch
from torch import nn

# %%
class Generator(nn.Module):
    def __init__(self, noise_channels, image_channels, features):
        super(Generator, self).__init__()
        
        # define the model
        self.model = nn.Sequential(
            # Transpose block 1
            nn.ConvTranspose2d(noise_channels, features*16, kernel_size=4, stride=1, padding=0),
            nn.ReLU(),

            # Transpose block 2
            nn.ConvTranspose2d(features*16, features*8, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(features*8),
            nn.ReLU(),

            # Transpose block 3
            nn.ConvTranspose2d(features*8, features*4, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(features*4),
            nn.ReLU(),

            # Transpose block 4
            nn.ConvTranspose2d(features*4, features*2, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(features*2),
            nn.ReLU(),

            # Last transpose block (different)
            nn.ConvTranspose2d(features*2, image_channels, kernel_size=4, stride=2, padding=1),
            nn.Tanh(),
        )
    
    def forward(self, x):
        return self.model(x)

# %%
class Discriminator(nn.Module):
    def __init__(self, image_channels, features):
        super(Discriminator, self).__init__()
        
        # define the model
        self.model = nn.Sequential(
            # define the first Conv block
            nn.Conv2d(image_channels, features, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2),

            # Conv block 2 
            nn.Conv2d(features, features*2, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(features*2),
            nn.LeakyReLU(0.2),
    
            # Conv block 3
            nn.Conv2d(features*2, features*4, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(features*4),
            nn.LeakyReLU(0.2),

            # Conv block 4
            nn.Conv2d(features*4, features*8, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(features*8),
            nn.LeakyReLU(0.2),

            # Conv block 5 (different)
            nn.Conv2d(features*8, 1, kernel_size=4, stride=2, padding=0),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.model(x)

# %%
import torch
import torchvision
from torch import nn
from torch import optim
from torchvision.datasets import FashionMNIST
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

# %%
LEARNING_RATE = 0.0005
BATCH_SIZE = 256
IMAGE_SIZE = 64
EPOCHS = 1
image_channels = 1
noise_channels = 256
gen_features = 64
disc_features = 64

# %%
device = torch.device("cuda")

# %%
data_transforms = transforms.Compose([
        transforms.Resize(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,)),
])

# %%
dataset = FashionMNIST(root="dataset/", train=True, transform=data_transforms, download=True)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to dataset/FashionMNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:10<00:00, 2532154.31it/s]
# Extracting dataset/FashionMNIST\raw\train-images-idx3-ubyte.gz to dataset/FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to dataset/FashionMNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 194284.05it/s]
# Extracting dataset/FashionMNIST\raw\train-labels-idx1-ubyte.gz to dataset/FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to dataset/FashionMNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:01<00:00, 3140782.02it/s]
# Extracting dataset/FashionMNIST\raw\t10k-images-idx3-ubyte.gz to dataset/FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to dataset/FashionMNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 5139794.57it/s]
# Extracting dataset/FashionMNIST\raw\t10k-labels-idx1-ubyte.gz to dataset/FashionMNIST\raw

# %%
gen_model  = Generator(noise_channels, image_channels, gen_features).to(device)
disc_model = Discriminator(image_channels, disc_features).to(device)

# %%
gen_optimizer = optim.Adam(gen_model.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
disc_optimizer = optim.Adam(disc_model.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))

# %%
criterion = nn.BCELoss()

# %%
gen_model.train()
disc_model.train()
# Out:
# Discriminator(
#   (model): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#     (12): Sigmoid()
#   )
# )

# %%
fake_label = 0
real_label = 1

# %%
fixed_noise = torch.randn(64, noise_channels, 1, 1).to(device)

# %%
writer_real = SummaryWriter(f"runs/fashion/test_real")
writer_fake = SummaryWriter(f"runs/fashion/test_fake")

# %%
step = 0

print("Start training...")

# loop over all epochs and all data
for epoch in range(EPOCHS):
    for batch_idx, (data, target) in enumerate(dataloader):
        # set the data to cuda
        data = data.to(device)

        # get the batch size 
        batch_size = data.shape[0]

        # Train the discriminator model on real data
        disc_model.zero_grad()
        label = (torch.ones(batch_size) * 0.9).to(device)
        output = disc_model(data).reshape(-1)
        real_disc_loss = criterion(output, label)
        d_x = output.mean().item()

        # train the disc model on fake (generated) data
        noise = torch.randn(batch_size, noise_channels, 1, 1).to(device)
        fake = gen_model(noise)
        label = (torch.ones(batch_size) * 0.1).to(device)
        output = disc_model(fake.detach()).reshape(-1)
        fake_disc_loss = criterion(output, label)

        # calculate the final discriminator loss
        disc_loss = real_disc_loss + fake_disc_loss

        # apply the optimizer and gradient
        disc_loss.backward()
        disc_optimizer.step()

        # train the generator model
        gen_model.zero_grad()
        label = torch.ones(batch_size).to(device)
        output = disc_model(fake).reshape(-1)
        gen_loss = criterion(output, label)
        # apply the optimizer and gradient
        gen_loss.backward()
        gen_optimizer.step()

        # print losses in console and tensorboard
        if batch_idx % 50 == 0:
            step += 1

            # print everything
            print(
                f"Epoch: {epoch} ===== Batch: {batch_idx}/{len(dataloader)} ===== Disc loss: {disc_loss:.4f} ===== Gen loss: {gen_loss:.4f}"
            )

            ### test the model
            with torch.no_grad():
                # generate fake images 
                fake_images = gen_model(fixed_noise)
                # make grid in the tensorboard
                img_grid_real = torchvision.utils.make_grid(data[:40], normalize=True)
                img_grid_fake = torchvision.utils.make_grid(fake_images[:40], normalize=True)

                # write the images in tensorbaord
                writer_real.add_image(
                    "Real images", img_grid_real, global_step=step
                )
                writer_fake.add_image(
                    "Generated images", img_grid_fake, global_step=step
                )

torch.save(gen_model.state_dict(), 'generator.pth')
torch.save(disc_model.state_dict(), 'discriminator.pth')
# Out:
# Start training...
# Epoch: 0 ===== Batch: 0/235 ===== Disc loss: 1.3244 ===== Gen loss: 4.7615
# Epoch: 0 ===== Batch: 50/235 ===== Disc loss: 0.7110 ===== Gen loss: 3.8341
# Epoch: 0 ===== Batch: 100/235 ===== Disc loss: 0.9928 ===== Gen loss: 2.7209
# Epoch: 0 ===== Batch: 150/235 ===== Disc loss: 1.5673 ===== Gen loss: 1.4963
# Epoch: 0 ===== Batch: 200/235 ===== Disc loss: 1.3150 ===== Gen loss: 0.7328
# Epoch: 1 ===== Batch: 0/235 ===== Disc loss: 1.4046 ===== Gen loss: 1.0636
# Epoch: 1 ===== Batch: 50/235 ===== Disc loss: 1.3251 ===== Gen loss: 1.5272
# Epoch: 1 ===== Batch: 100/235 ===== Disc loss: 1.2744 ===== Gen loss: 0.9195
# Epoch: 1 ===== Batch: 150/235 ===== Disc loss: 1.1953 ===== Gen loss: 1.2379
# Epoch: 1 ===== Batch: 200/235 ===== Disc loss: 1.3124 ===== Gen loss: 1.9362
# Epoch: 2 ===== Batch: 0/235 ===== Disc loss: 1.2530 ===== Gen loss: 1.0874
# Epoch: 2 ===== Batch: 50/235 ===== Disc loss: 1.1948 ===== Gen loss: 1.0828
# Epoch: 2 ===== Batch: 100/235 ===== Disc loss: 1.5366 ===== Gen loss: 0.5491
# Epoch: 2 ===== Batch: 150/235 ===== Disc loss: 1.1480 ===== Gen loss: 1.1647
# Epoch: 2 ===== Batch: 200/235 ===== Disc loss: 0.9286 ===== Gen loss: 1.2447
# Epoch: 3 ===== Batch: 0/235 ===== Disc loss: 1.4585 ===== Gen loss: 2.4505
# Epoch: 3 ===== Batch: 50/235 ===== Disc loss: 1.2123 ===== Gen loss: 1.7698
# Epoch: 3 ===== Batch: 100/235 ===== Disc loss: 1.1082 ===== Gen loss: 1.8284
# Epoch: 3 ===== Batch: 150/235 ===== Disc loss: 1.0865 ===== Gen loss: 1.4721
# Epoch: 3 ===== Batch: 200/235 ===== Disc loss: 1.1464 ===== Gen loss: 1.7924
# Epoch: 4 ===== Batch: 0/235 ===== Disc loss: 1.0004 ===== Gen loss: 1.6854
# Epoch: 4 ===== Batch: 50/235 ===== Disc loss: 1.0107 ===== Gen loss: 1.5065
# Epoch: 4 ===== Batch: 100/235 ===== Disc loss: 1.0030 ===== Gen loss: 3.5194
# Epoch: 4 ===== Batch: 150/235 ===== Disc loss: 1.0139 ===== Gen loss: 2.6736
# Epoch: 4 ===== Batch: 200/235 ===== Disc loss: 1.2754 ===== Gen loss: 3.4771
# Epoch: 5 ===== Batch: 0/235 ===== Disc loss: 0.9071 ===== Gen loss: 1.6270
# Epoch: 5 ===== Batch: 50/235 ===== Disc loss: 1.0554 ===== Gen loss: 2.6807
# Epoch: 5 ===== Batch: 100/235 ===== Disc loss: 0.7651 ===== Gen loss: 2.2934
# Epoch: 5 ===== Batch: 150/235 ===== Disc loss: 1.0387 ===== Gen loss: 1.4627
# Epoch: 5 ===== Batch: 200/235 ===== Disc loss: 1.1288 ===== Gen loss: 2.8229
# Epoch: 6 ===== Batch: 0/235 ===== Disc loss: 1.2050 ===== Gen loss: 2.3011
# Epoch: 6 ===== Batch: 50/235 ===== Disc loss: 0.9663 ===== Gen loss: 3.2092
# Epoch: 6 ===== Batch: 100/235 ===== Disc loss: 0.7570 ===== Gen loss: 1.7877
# Epoch: 6 ===== Batch: 150/235 ===== Disc loss: 0.7613 ===== Gen loss: 2.7809
# Epoch: 6 ===== Batch: 200/235 ===== Disc loss: 0.8073 ===== Gen loss: 2.5332
# Epoch: 7 ===== Batch: 0/235 ===== Disc loss: 1.2490 ===== Gen loss: 4.2575
# Epoch: 7 ===== Batch: 50/235 ===== Disc loss: 0.8715 ===== Gen loss: 1.8178
# Epoch: 7 ===== Batch: 100/235 ===== Disc loss: 0.7314 ===== Gen loss: 2.9451
# Epoch: 7 ===== Batch: 150/235 ===== Disc loss: 0.8708 ===== Gen loss: 2.6626
# Epoch: 7 ===== Batch: 200/235 ===== Disc loss: 0.7921 ===== Gen loss: 2.1140
# Epoch: 8 ===== Batch: 0/235 ===== Disc loss: 0.6880 ===== Gen loss: 2.3333
# Epoch: 8 ===== Batch: 50/235 ===== Disc loss: 1.1367 ===== Gen loss: 3.6404
# Epoch: 8 ===== Batch: 100/235 ===== Disc loss: 0.7865 ===== Gen loss: 2.7955
# Epoch: 8 ===== Batch: 150/235 ===== Disc loss: 0.8792 ===== Gen loss: 3.0370
# Epoch: 8 ===== Batch: 200/235 ===== Disc loss: 1.0709 ===== Gen loss: 3.7317
# Epoch: 9 ===== Batch: 0/235 ===== Disc loss: 1.0057 ===== Gen loss: 1.3445
# Epoch: 9 ===== Batch: 50/235 ===== Disc loss: 1.1858 ===== Gen loss: 1.2484
# Epoch: 9 ===== Batch: 100/235 ===== Disc loss: 1.1347 ===== Gen loss: 4.2985
# Epoch: 9 ===== Batch: 150/235 ===== Disc loss: 0.8490 ===== Gen loss: 3.3514
# Epoch: 9 ===== Batch: 200/235 ===== Disc loss: 0.7157 ===== Gen loss: 2.3869
# Epoch: 10 ===== Batch: 0/235 ===== Disc loss: 0.7257 ===== Gen loss: 2.0925
# Epoch: 10 ===== Batch: 50/235 ===== Disc loss: 0.7416 ===== Gen loss: 2.2184
# Epoch: 10 ===== Batch: 100/235 ===== Disc loss: 0.7939 ===== Gen loss: 2.0745
# Epoch: 10 ===== Batch: 150/235 ===== Disc loss: 0.6948 ===== Gen loss: 2.3373
# Epoch: 10 ===== Batch: 200/235 ===== Disc loss: 0.8284 ===== Gen loss: 3.4334
# Epoch: 11 ===== Batch: 0/235 ===== Disc loss: 0.7642 ===== Gen loss: 2.2175
# Epoch: 11 ===== Batch: 50/235 ===== Disc loss: 0.6968 ===== Gen loss: 2.6105
# Epoch: 11 ===== Batch: 100/235 ===== Disc loss: 0.6820 ===== Gen loss: 2.2242
# Epoch: 11 ===== Batch: 150/235 ===== Disc loss: 1.0711 ===== Gen loss: 1.9130
# Epoch: 11 ===== Batch: 200/235 ===== Disc loss: 0.6900 ===== Gen loss: 2.0707
# Epoch: 12 ===== Batch: 0/235 ===== Disc loss: 0.7421 ===== Gen loss: 2.1975
# Epoch: 12 ===== Batch: 50/235 ===== Disc loss: 0.7379 ===== Gen loss: 2.3118
# Epoch: 12 ===== Batch: 100/235 ===== Disc loss: 0.7722 ===== Gen loss: 3.4016
# Epoch: 12 ===== Batch: 150/235 ===== Disc loss: 0.6782 ===== Gen loss: 2.3415
# Epoch: 12 ===== Batch: 200/235 ===== Disc loss: 1.0608 ===== Gen loss: 3.9777
# Epoch: 13 ===== Batch: 0/235 ===== Disc loss: 0.7110 ===== Gen loss: 2.2430
# Epoch: 13 ===== Batch: 50/235 ===== Disc loss: 0.7561 ===== Gen loss: 3.3461
# Epoch: 13 ===== Batch: 100/235 ===== Disc loss: 0.9548 ===== Gen loss: 3.9870
# Epoch: 13 ===== Batch: 150/235 ===== Disc loss: 0.6963 ===== Gen loss: 2.4216
# Epoch: 13 ===== Batch: 200/235 ===== Disc loss: 1.0420 ===== Gen loss: 1.5075
# Epoch: 14 ===== Batch: 0/235 ===== Disc loss: 0.7513 ===== Gen loss: 2.0121
# Epoch: 14 ===== Batch: 50/235 ===== Disc loss: 0.7058 ===== Gen loss: 2.3133
# Epoch: 14 ===== Batch: 100/235 ===== Disc loss: 0.7018 ===== Gen loss: 2.4303
# Epoch: 14 ===== Batch: 150/235 ===== Disc loss: 0.7466 ===== Gen loss: 2.9786
# Epoch: 14 ===== Batch: 200/235 ===== Disc loss: 0.8082 ===== Gen loss: 2.3426
# Epoch: 15 ===== Batch: 0/235 ===== Disc loss: 0.7262 ===== Gen loss: 2.5790
# Epoch: 15 ===== Batch: 50/235 ===== Disc loss: 0.7824 ===== Gen loss: 2.7293
# Epoch: 15 ===== Batch: 100/235 ===== Disc loss: 0.7378 ===== Gen loss: 1.9001
# Epoch: 15 ===== Batch: 150/235 ===== Disc loss: 0.6717 ===== Gen loss: 2.3665
# Epoch: 15 ===== Batch: 200/235 ===== Disc loss: 0.7153 ===== Gen loss: 1.8976
# Epoch: 16 ===== Batch: 0/235 ===== Disc loss: 0.9546 ===== Gen loss: 3.9450
# Epoch: 16 ===== Batch: 50/235 ===== Disc loss: 0.6980 ===== Gen loss: 1.9090
# Epoch: 16 ===== Batch: 100/235 ===== Disc loss: 0.8355 ===== Gen loss: 2.7272
# Epoch: 16 ===== Batch: 150/235 ===== Disc loss: 0.6901 ===== Gen loss: 2.5361
# Epoch: 16 ===== Batch: 200/235 ===== Disc loss: 0.7420 ===== Gen loss: 3.1701
# Epoch: 17 ===== Batch: 0/235 ===== Disc loss: 0.6951 ===== Gen loss: 2.1108
# Epoch: 17 ===== Batch: 50/235 ===== Disc loss: 0.6957 ===== Gen loss: 2.6765
# Epoch: 17 ===== Batch: 100/235 ===== Disc loss: 0.6740 ===== Gen loss: 2.2973
# Epoch: 17 ===== Batch: 150/235 ===== Disc loss: 0.6655 ===== Gen loss: 2.3040
# Epoch: 17 ===== Batch: 200/235 ===== Disc loss: 0.7362 ===== Gen loss: 3.0515
# Epoch: 18 ===== Batch: 0/235 ===== Disc loss: 0.6833 ===== Gen loss: 2.5722
# Epoch: 18 ===== Batch: 50/235 ===== Disc loss: 0.6740 ===== Gen loss: 2.2506
# Epoch: 18 ===== Batch: 100/235 ===== Disc loss: 0.6723 ===== Gen loss: 2.4216
# Epoch: 18 ===== Batch: 150/235 ===== Disc loss: 1.2287 ===== Gen loss: 2.1495
# Epoch: 18 ===== Batch: 200/235 ===== Disc loss: 0.6770 ===== Gen loss: 2.2731
# Epoch: 19 ===== Batch: 0/235 ===== Disc loss: 0.8109 ===== Gen loss: 2.5475
# Epoch: 19 ===== Batch: 50/235 ===== Disc loss: 0.7936 ===== Gen loss: 2.3600
# Epoch: 19 ===== Batch: 100/235 ===== Disc loss: 0.7601 ===== Gen loss: 2.6616
# Epoch: 19 ===== Batch: 150/235 ===== Disc loss: 0.6730 ===== Gen loss: 2.6485
# Epoch: 19 ===== Batch: 200/235 ===== Disc loss: 0.7094 ===== Gen loss: 2.7040
# Epoch: 20 ===== Batch: 0/235 ===== Disc loss: 0.8015 ===== Gen loss: 2.2965
# Epoch: 20 ===== Batch: 50/235 ===== Disc loss: 0.7596 ===== Gen loss: 3.1087
# Epoch: 20 ===== Batch: 100/235 ===== Disc loss: 0.6654 ===== Gen loss: 2.3830
# Epoch: 20 ===== Batch: 150/235 ===== Disc loss: 0.7061 ===== Gen loss: 2.2140
# Epoch: 20 ===== Batch: 200/235 ===== Disc loss: 0.6847 ===== Gen loss: 2.3639
# Epoch: 21 ===== Batch: 0/235 ===== Disc loss: 0.6924 ===== Gen loss: 2.2083
# Epoch: 21 ===== Batch: 50/235 ===== Disc loss: 0.6632 ===== Gen loss: 2.2940
# Epoch: 21 ===== Batch: 100/235 ===== Disc loss: 0.7647 ===== Gen loss: 3.9198
# Epoch: 21 ===== Batch: 150/235 ===== Disc loss: 0.7791 ===== Gen loss: 3.2817
# Epoch: 21 ===== Batch: 200/235 ===== Disc loss: 0.6742 ===== Gen loss: 2.4782
# Epoch: 22 ===== Batch: 0/235 ===== Disc loss: 0.6733 ===== Gen loss: 2.1758
# Epoch: 22 ===== Batch: 50/235 ===== Disc loss: 0.7554 ===== Gen loss: 3.3850
# Epoch: 22 ===== Batch: 100/235 ===== Disc loss: 0.8089 ===== Gen loss: 1.5162
# Epoch: 22 ===== Batch: 150/235 ===== Disc loss: 0.6870 ===== Gen loss: 2.0727
# Epoch: 22 ===== Batch: 200/235 ===== Disc loss: 0.7161 ===== Gen loss: 2.0067
# Epoch: 23 ===== Batch: 0/235 ===== Disc loss: 0.6926 ===== Gen loss: 2.3258
# Epoch: 23 ===== Batch: 50/235 ===== Disc loss: 0.6709 ===== Gen loss: 2.3630
# Epoch: 23 ===== Batch: 100/235 ===== Disc loss: 0.6741 ===== Gen loss: 2.1871
# Epoch: 23 ===== Batch: 150/235 ===== Disc loss: 0.8051 ===== Gen loss: 2.3903
# Epoch: 23 ===== Batch: 200/235 ===== Disc loss: 0.6650 ===== Gen loss: 2.2105
# Epoch: 24 ===== Batch: 0/235 ===== Disc loss: 0.6647 ===== Gen loss: 2.4242
# Epoch: 24 ===== Batch: 50/235 ===== Disc loss: 1.0557 ===== Gen loss: 0.8142
# Epoch: 24 ===== Batch: 100/235 ===== Disc loss: 0.6859 ===== Gen loss: 2.7274
# Epoch: 24 ===== Batch: 150/235 ===== Disc loss: 0.6659 ===== Gen loss: 2.4389
# Epoch: 24 ===== Batch: 200/235 ===== Disc loss: 0.6643 ===== Gen loss: 2.4486
# Epoch: 25 ===== Batch: 0/235 ===== Disc loss: 0.6742 ===== Gen loss: 2.5043
# Epoch: 25 ===== Batch: 50/235 ===== Disc loss: 2.8577 ===== Gen loss: 0.5524
# Epoch: 25 ===== Batch: 100/235 ===== Disc loss: 0.6834 ===== Gen loss: 2.7812
# Epoch: 25 ===== Batch: 150/235 ===== Disc loss: 0.6876 ===== Gen loss: 2.5463
# Epoch: 25 ===== Batch: 200/235 ===== Disc loss: 0.7656 ===== Gen loss: 3.2004
# Epoch: 26 ===== Batch: 0/235 ===== Disc loss: 0.6971 ===== Gen loss: 2.3731
# Epoch: 26 ===== Batch: 50/235 ===== Disc loss: 0.8483 ===== Gen loss: 2.7431
# Epoch: 26 ===== Batch: 100/235 ===== Disc loss: 0.7480 ===== Gen loss: 2.7179
# Epoch: 26 ===== Batch: 150/235 ===== Disc loss: 0.7119 ===== Gen loss: 3.9200
# Epoch: 26 ===== Batch: 200/235 ===== Disc loss: 0.6854 ===== Gen loss: 2.8353
# Epoch: 27 ===== Batch: 0/235 ===== Disc loss: 1.0564 ===== Gen loss: 0.8407
# Epoch: 27 ===== Batch: 50/235 ===== Disc loss: 0.6664 ===== Gen loss: 2.2783
# Epoch: 27 ===== Batch: 100/235 ===== Disc loss: 0.6687 ===== Gen loss: 2.2109
# Epoch: 27 ===== Batch: 150/235 ===== Disc loss: 0.9070 ===== Gen loss: 4.3405
# Epoch: 27 ===== Batch: 200/235 ===== Disc loss: 1.0554 ===== Gen loss: 4.7100
# Epoch: 28 ===== Batch: 0/235 ===== Disc loss: 0.6819 ===== Gen loss: 2.6641
# Epoch: 28 ===== Batch: 50/235 ===== Disc loss: 0.6863 ===== Gen loss: 2.5442
# Epoch: 28 ===== Batch: 100/235 ===== Disc loss: 0.6943 ===== Gen loss: 3.0239
# Epoch: 28 ===== Batch: 150/235 ===== Disc loss: 0.7101 ===== Gen loss: 2.2353
# Epoch: 28 ===== Batch: 200/235 ===== Disc loss: 0.7049 ===== Gen loss: 3.0803
# Epoch: 29 ===== Batch: 0/235 ===== Disc loss: 0.7349 ===== Gen loss: 4.6158
# Epoch: 29 ===== Batch: 50/235 ===== Disc loss: 0.6624 ===== Gen loss: 2.3796
# Epoch: 29 ===== Batch: 100/235 ===== Disc loss: 0.6913 ===== Gen loss: 2.3650
# Epoch: 29 ===== Batch: 150/235 ===== Disc loss: 0.8643 ===== Gen loss: 2.1676
# Epoch: 29 ===== Batch: 200/235 ===== Disc loss: 0.8822 ===== Gen loss: 1.6738
# Epoch: 30 ===== Batch: 0/235 ===== Disc loss: 0.7039 ===== Gen loss: 3.0304
# Epoch: 30 ===== Batch: 50/235 ===== Disc loss: 0.6621 ===== Gen loss: 2.3105
# Epoch: 30 ===== Batch: 100/235 ===== Disc loss: 0.6850 ===== Gen loss: 2.7975
# Epoch: 30 ===== Batch: 150/235 ===== Disc loss: 0.7070 ===== Gen loss: 3.1600
# Epoch: 30 ===== Batch: 200/235 ===== Disc loss: 2.9062 ===== Gen loss: 0.5869
# Epoch: 31 ===== Batch: 0/235 ===== Disc loss: 0.7251 ===== Gen loss: 3.0862
# Epoch: 31 ===== Batch: 50/235 ===== Disc loss: 0.6729 ===== Gen loss: 2.2434
# Epoch: 31 ===== Batch: 100/235 ===== Disc loss: 0.6911 ===== Gen loss: 2.3391
# Epoch: 31 ===== Batch: 150/235 ===== Disc loss: 0.6641 ===== Gen loss: 2.2864
# Epoch: 31 ===== Batch: 200/235 ===== Disc loss: 0.7062 ===== Gen loss: 3.0599
# Epoch: 32 ===== Batch: 0/235 ===== Disc loss: 0.6716 ===== Gen loss: 2.6135
# Epoch: 32 ===== Batch: 50/235 ===== Disc loss: 0.6805 ===== Gen loss: 2.6658
# Epoch: 32 ===== Batch: 100/235 ===== Disc loss: 0.7879 ===== Gen loss: 2.1204
# Epoch: 32 ===== Batch: 150/235 ===== Disc loss: 0.7819 ===== Gen loss: 2.3636
# Epoch: 32 ===== Batch: 200/235 ===== Disc loss: 0.7226 ===== Gen loss: 2.9223
# Epoch: 33 ===== Batch: 0/235 ===== Disc loss: 0.7274 ===== Gen loss: 1.8341
# Epoch: 33 ===== Batch: 50/235 ===== Disc loss: 0.6730 ===== Gen loss: 2.5360
# Epoch: 33 ===== Batch: 100/235 ===== Disc loss: 0.6684 ===== Gen loss: 2.6458
# Epoch: 33 ===== Batch: 150/235 ===== Disc loss: 0.7111 ===== Gen loss: 2.3639
# Epoch: 33 ===== Batch: 200/235 ===== Disc loss: 0.6756 ===== Gen loss: 2.2768
# Epoch: 34 ===== Batch: 0/235 ===== Disc loss: 0.6754 ===== Gen loss: 2.5957
# Epoch: 34 ===== Batch: 50/235 ===== Disc loss: 0.6719 ===== Gen loss: 2.7383
# Epoch: 34 ===== Batch: 100/235 ===== Disc loss: 0.6770 ===== Gen loss: 2.5763
# Epoch: 34 ===== Batch: 150/235 ===== Disc loss: 0.6690 ===== Gen loss: 2.5022
# Epoch: 34 ===== Batch: 200/235 ===== Disc loss: 0.6683 ===== Gen loss: 2.1823
# Epoch: 35 ===== Batch: 0/235 ===== Disc loss: 0.6725 ===== Gen loss: 2.4911
# Epoch: 35 ===== Batch: 50/235 ===== Disc loss: 0.6903 ===== Gen loss: 2.8048
# Epoch: 35 ===== Batch: 100/235 ===== Disc loss: 0.6666 ===== Gen loss: 2.2977
# Epoch: 35 ===== Batch: 150/235 ===== Disc loss: 0.6672 ===== Gen loss: 2.2791
# Epoch: 35 ===== Batch: 200/235 ===== Disc loss: 0.6746 ===== Gen loss: 2.7278
# Epoch: 36 ===== Batch: 0/235 ===== Disc loss: 0.7371 ===== Gen loss: 2.2206
# Epoch: 36 ===== Batch: 50/235 ===== Disc loss: 0.6831 ===== Gen loss: 2.9683
# Epoch: 36 ===== Batch: 100/235 ===== Disc loss: 0.6659 ===== Gen loss: 2.4920
# Epoch: 36 ===== Batch: 150/235 ===== Disc loss: 0.7748 ===== Gen loss: 3.5083
# Epoch: 36 ===== Batch: 200/235 ===== Disc loss: 0.6637 ===== Gen loss: 2.0024
# Epoch: 37 ===== Batch: 0/235 ===== Disc loss: 0.6758 ===== Gen loss: 1.7364
# Epoch: 37 ===== Batch: 50/235 ===== Disc loss: 0.7045 ===== Gen loss: 2.0433
# Epoch: 37 ===== Batch: 100/235 ===== Disc loss: 0.6663 ===== Gen loss: 2.4509
# Epoch: 37 ===== Batch: 150/235 ===== Disc loss: 0.6688 ===== Gen loss: 2.4733
# Epoch: 37 ===== Batch: 200/235 ===== Disc loss: 0.6600 ===== Gen loss: 2.5069
# Epoch: 38 ===== Batch: 0/235 ===== Disc loss: 0.6601 ===== Gen loss: 2.2899
# Epoch: 38 ===== Batch: 50/235 ===== Disc loss: 0.7017 ===== Gen loss: 2.9050
# Epoch: 38 ===== Batch: 100/235 ===== Disc loss: 0.6774 ===== Gen loss: 2.1413
# Epoch: 38 ===== Batch: 150/235 ===== Disc loss: 0.6675 ===== Gen loss: 2.6442
# Epoch: 38 ===== Batch: 200/235 ===== Disc loss: 0.6698 ===== Gen loss: 2.2034
# Epoch: 39 ===== Batch: 0/235 ===== Disc loss: 0.9826 ===== Gen loss: 5.2889
# Epoch: 39 ===== Batch: 50/235 ===== Disc loss: 0.6914 ===== Gen loss: 2.8673
# Epoch: 39 ===== Batch: 100/235 ===== Disc loss: 0.7035 ===== Gen loss: 2.3905
# Epoch: 39 ===== Batch: 150/235 ===== Disc loss: 0.7253 ===== Gen loss: 2.3037
# Epoch: 39 ===== Batch: 200/235 ===== Disc loss: 0.6767 ===== Gen loss: 2.2827
# Epoch: 40 ===== Batch: 0/235 ===== Disc loss: 0.6655 ===== Gen loss: 2.1354
# Epoch: 40 ===== Batch: 50/235 ===== Disc loss: 0.7915 ===== Gen loss: 4.1380
# Epoch: 40 ===== Batch: 100/235 ===== Disc loss: 0.6731 ===== Gen loss: 2.0638
# Epoch: 40 ===== Batch: 150/235 ===== Disc loss: 0.6942 ===== Gen loss: 2.2018
# Epoch: 40 ===== Batch: 200/235 ===== Disc loss: 0.8246 ===== Gen loss: 1.3515
# Epoch: 41 ===== Batch: 0/235 ===== Disc loss: 0.7218 ===== Gen loss: 1.8542
# Epoch: 41 ===== Batch: 50/235 ===== Disc loss: 0.6975 ===== Gen loss: 3.2190
# Epoch: 41 ===== Batch: 100/235 ===== Disc loss: 0.6897 ===== Gen loss: 2.7571
# Epoch: 41 ===== Batch: 150/235 ===== Disc loss: 0.7326 ===== Gen loss: 2.3768
# Epoch: 41 ===== Batch: 200/235 ===== Disc loss: 0.6663 ===== Gen loss: 2.4834
# Epoch: 42 ===== Batch: 0/235 ===== Disc loss: 0.6620 ===== Gen loss: 2.4687
# Epoch: 42 ===== Batch: 50/235 ===== Disc loss: 0.6928 ===== Gen loss: 1.9462
# Epoch: 42 ===== Batch: 100/235 ===== Disc loss: 0.6680 ===== Gen loss: 2.5559
# Epoch: 42 ===== Batch: 150/235 ===== Disc loss: 0.6637 ===== Gen loss: 2.1700
# Epoch: 42 ===== Batch: 200/235 ===== Disc loss: 0.6637 ===== Gen loss: 2.4720
# Epoch: 43 ===== Batch: 0/235 ===== Disc loss: 0.6643 ===== Gen loss: 2.4631
# Epoch: 43 ===== Batch: 50/235 ===== Disc loss: 0.6596 ===== Gen loss: 2.4557
# Epoch: 43 ===== Batch: 100/235 ===== Disc loss: 0.6772 ===== Gen loss: 2.7858
# Epoch: 43 ===== Batch: 150/235 ===== Disc loss: 0.7764 ===== Gen loss: 1.5694
# Epoch: 43 ===== Batch: 200/235 ===== Disc loss: 0.6667 ===== Gen loss: 2.4374
# Epoch: 44 ===== Batch: 0/235 ===== Disc loss: 0.7370 ===== Gen loss: 1.9165
# Epoch: 44 ===== Batch: 50/235 ===== Disc loss: 0.6707 ===== Gen loss: 2.5422
# Epoch: 44 ===== Batch: 100/235 ===== Disc loss: 0.6722 ===== Gen loss: 2.9830
# Epoch: 44 ===== Batch: 150/235 ===== Disc loss: 0.7710 ===== Gen loss: 2.4751
# Epoch: 44 ===== Batch: 200/235 ===== Disc loss: 0.6714 ===== Gen loss: 2.2484
# Epoch: 45 ===== Batch: 0/235 ===== Disc loss: 0.7923 ===== Gen loss: 3.6690
# Epoch: 45 ===== Batch: 50/235 ===== Disc loss: 0.6628 ===== Gen loss: 2.3448
# Epoch: 45 ===== Batch: 100/235 ===== Disc loss: 0.6784 ===== Gen loss: 2.0450
# Epoch: 45 ===== Batch: 150/235 ===== Disc loss: 0.6838 ===== Gen loss: 2.1450
# Epoch: 45 ===== Batch: 200/235 ===== Disc loss: 0.6673 ===== Gen loss: 2.3764
# Epoch: 46 ===== Batch: 0/235 ===== Disc loss: 0.9259 ===== Gen loss: 1.8863
# Epoch: 46 ===== Batch: 50/235 ===== Disc loss: 0.7335 ===== Gen loss: 1.9573
# Epoch: 46 ===== Batch: 100/235 ===== Disc loss: 0.6754 ===== Gen loss: 2.4830
# Epoch: 46 ===== Batch: 150/235 ===== Disc loss: 0.6669 ===== Gen loss: 2.5671
# Epoch: 46 ===== Batch: 200/235 ===== Disc loss: 0.7021 ===== Gen loss: 1.8872
# Epoch: 47 ===== Batch: 0/235 ===== Disc loss: 0.6713 ===== Gen loss: 2.3343
# Epoch: 47 ===== Batch: 50/235 ===== Disc loss: 0.6902 ===== Gen loss: 2.1071
# Epoch: 47 ===== Batch: 100/235 ===== Disc loss: 0.6682 ===== Gen loss: 2.4097
# Epoch: 47 ===== Batch: 150/235 ===== Disc loss: 0.6838 ===== Gen loss: 2.4418
# Epoch: 47 ===== Batch: 200/235 ===== Disc loss: 0.6681 ===== Gen loss: 2.4228
# Epoch: 48 ===== Batch: 0/235 ===== Disc loss: 0.6678 ===== Gen loss: 1.8740
# Epoch: 48 ===== Batch: 50/235 ===== Disc loss: 0.6627 ===== Gen loss: 2.4304
# Epoch: 48 ===== Batch: 100/235 ===== Disc loss: 0.6763 ===== Gen loss: 2.0156
# Epoch: 48 ===== Batch: 150/235 ===== Disc loss: 0.7289 ===== Gen loss: 3.3006
# Epoch: 48 ===== Batch: 200/235 ===== Disc loss: 0.6596 ===== Gen loss: 2.2303
# Epoch: 49 ===== Batch: 0/235 ===== Disc loss: 0.8515 ===== Gen loss: 2.0069
# Epoch: 49 ===== Batch: 50/235 ===== Disc loss: 0.8722 ===== Gen loss: 1.9800
# Epoch: 49 ===== Batch: 100/235 ===== Disc loss: 0.6858 ===== Gen loss: 2.9565
# Epoch: 49 ===== Batch: 150/235 ===== Disc loss: 0.6750 ===== Gen loss: 2.5063
# Epoch: 49 ===== Batch: 200/235 ===== Disc loss: 0.6853 ===== Gen loss: 2.5681
# Epoch: 50 ===== Batch: 0/235 ===== Disc loss: 0.6608 ===== Gen loss: 2.6532
# Epoch: 50 ===== Batch: 50/235 ===== Disc loss: 0.6777 ===== Gen loss: 2.0715
# Epoch: 50 ===== Batch: 100/235 ===== Disc loss: 0.6633 ===== Gen loss: 2.3518
# Epoch: 50 ===== Batch: 150/235 ===== Disc loss: 0.6824 ===== Gen loss: 1.8378
# Epoch: 50 ===== Batch: 200/235 ===== Disc loss: 0.6967 ===== Gen loss: 1.7577
# Epoch: 51 ===== Batch: 0/235 ===== Disc loss: 0.9138 ===== Gen loss: 4.0525
# Epoch: 51 ===== Batch: 50/235 ===== Disc loss: 0.6695 ===== Gen loss: 2.5410
# Epoch: 51 ===== Batch: 100/235 ===== Disc loss: 0.6639 ===== Gen loss: 2.4575
# Epoch: 51 ===== Batch: 150/235 ===== Disc loss: 0.6590 ===== Gen loss: 2.2676
# Epoch: 51 ===== Batch: 200/235 ===== Disc loss: 0.6731 ===== Gen loss: 3.0216
# Epoch: 52 ===== Batch: 0/235 ===== Disc loss: 0.7562 ===== Gen loss: 3.1968
# Epoch: 52 ===== Batch: 50/235 ===== Disc loss: 0.6907 ===== Gen loss: 3.1981
# Epoch: 52 ===== Batch: 100/235 ===== Disc loss: 0.7567 ===== Gen loss: 3.2319
# Epoch: 52 ===== Batch: 150/235 ===== Disc loss: 0.6711 ===== Gen loss: 2.6792
# Epoch: 52 ===== Batch: 200/235 ===== Disc loss: 0.6666 ===== Gen loss: 2.6598
# Epoch: 53 ===== Batch: 0/235 ===== Disc loss: 0.6889 ===== Gen loss: 2.7901
# Epoch: 53 ===== Batch: 50/235 ===== Disc loss: 0.7065 ===== Gen loss: 3.2148
# Epoch: 53 ===== Batch: 100/235 ===== Disc loss: 0.6920 ===== Gen loss: 2.1265
# Epoch: 53 ===== Batch: 150/235 ===== Disc loss: 0.6698 ===== Gen loss: 2.6015
# Epoch: 53 ===== Batch: 200/235 ===== Disc loss: 0.6998 ===== Gen loss: 3.1777
# Epoch: 54 ===== Batch: 0/235 ===== Disc loss: 0.6627 ===== Gen loss: 2.3520
# Epoch: 54 ===== Batch: 50/235 ===== Disc loss: 0.6608 ===== Gen loss: 2.2244
# Epoch: 54 ===== Batch: 100/235 ===== Disc loss: 0.6681 ===== Gen loss: 2.3043
# Epoch: 54 ===== Batch: 150/235 ===== Disc loss: 0.7048 ===== Gen loss: 2.6295
# Epoch: 54 ===== Batch: 200/235 ===== Disc loss: 0.7294 ===== Gen loss: 1.9538
# Epoch: 55 ===== Batch: 0/235 ===== Disc loss: 0.7006 ===== Gen loss: 2.4915
# Epoch: 55 ===== Batch: 50/235 ===== Disc loss: 0.6653 ===== Gen loss: 2.4298
# Epoch: 55 ===== Batch: 100/235 ===== Disc loss: 0.6660 ===== Gen loss: 1.9584
# Epoch: 55 ===== Batch: 150/235 ===== Disc loss: 0.6619 ===== Gen loss: 2.2363
# Epoch: 55 ===== Batch: 200/235 ===== Disc loss: 0.6689 ===== Gen loss: 2.5176
# Epoch: 56 ===== Batch: 0/235 ===== Disc loss: 0.7076 ===== Gen loss: 1.9751
# Epoch: 56 ===== Batch: 50/235 ===== Disc loss: 0.7041 ===== Gen loss: 2.3447
# Epoch: 56 ===== Batch: 100/235 ===== Disc loss: 0.7361 ===== Gen loss: 2.7973
# Epoch: 56 ===== Batch: 150/235 ===== Disc loss: 0.6751 ===== Gen loss: 2.3072
# Epoch: 56 ===== Batch: 200/235 ===== Disc loss: 0.6605 ===== Gen loss: 2.2947
# Epoch: 57 ===== Batch: 0/235 ===== Disc loss: 0.6743 ===== Gen loss: 2.3419
# Epoch: 57 ===== Batch: 50/235 ===== Disc loss: 0.6673 ===== Gen loss: 2.4798
# Epoch: 57 ===== Batch: 100/235 ===== Disc loss: 0.6736 ===== Gen loss: 1.8985
# Epoch: 57 ===== Batch: 150/235 ===== Disc loss: 0.6987 ===== Gen loss: 1.8290
# Epoch: 57 ===== Batch: 200/235 ===== Disc loss: 0.6860 ===== Gen loss: 2.6135
# Epoch: 58 ===== Batch: 0/235 ===== Disc loss: 0.6819 ===== Gen loss: 2.1878
# Epoch: 58 ===== Batch: 50/235 ===== Disc loss: 0.6625 ===== Gen loss: 2.0080
# Epoch: 58 ===== Batch: 100/235 ===== Disc loss: 0.6678 ===== Gen loss: 2.1158
# Epoch: 58 ===== Batch: 150/235 ===== Disc loss: 0.7468 ===== Gen loss: 3.2026
# Epoch: 58 ===== Batch: 200/235 ===== Disc loss: 0.7125 ===== Gen loss: 2.9741
# Epoch: 59 ===== Batch: 0/235 ===== Disc loss: 0.6598 ===== Gen loss: 2.2467
# Epoch: 59 ===== Batch: 50/235 ===== Disc loss: 0.6618 ===== Gen loss: 2.4058
# Epoch: 59 ===== Batch: 100/235 ===== Disc loss: 0.6661 ===== Gen loss: 1.9777
# Epoch: 59 ===== Batch: 150/235 ===== Disc loss: 0.6579 ===== Gen loss: 2.5234
# Epoch: 59 ===== Batch: 200/235 ===== Disc loss: 1.1890 ===== Gen loss: 1.2970
# Epoch: 60 ===== Batch: 0/235 ===== Disc loss: 0.6970 ===== Gen loss: 2.8645
# Epoch: 60 ===== Batch: 50/235 ===== Disc loss: 0.6684 ===== Gen loss: 2.5775
# Epoch: 60 ===== Batch: 100/235 ===== Disc loss: 0.6724 ===== Gen loss: 2.6505
# Epoch: 60 ===== Batch: 150/235 ===== Disc loss: 0.7017 ===== Gen loss: 2.4325
# Epoch: 60 ===== Batch: 200/235 ===== Disc loss: 0.6617 ===== Gen loss: 2.5375
# Epoch: 61 ===== Batch: 0/235 ===== Disc loss: 1.2035 ===== Gen loss: 4.2305
# Epoch: 61 ===== Batch: 50/235 ===== Disc loss: 0.6787 ===== Gen loss: 1.9481
# Epoch: 61 ===== Batch: 100/235 ===== Disc loss: 0.6640 ===== Gen loss: 1.8356
# Epoch: 61 ===== Batch: 150/235 ===== Disc loss: 0.6628 ===== Gen loss: 2.3448
# Epoch: 61 ===== Batch: 200/235 ===== Disc loss: 0.7003 ===== Gen loss: 3.2677
# Epoch: 62 ===== Batch: 0/235 ===== Disc loss: 0.6759 ===== Gen loss: 2.3798
# Epoch: 62 ===== Batch: 50/235 ===== Disc loss: 0.6813 ===== Gen loss: 2.6669
# Epoch: 62 ===== Batch: 100/235 ===== Disc loss: 0.6658 ===== Gen loss: 2.0812
# Epoch: 62 ===== Batch: 150/235 ===== Disc loss: 0.6927 ===== Gen loss: 2.0021
# Epoch: 62 ===== Batch: 200/235 ===== Disc loss: 0.6812 ===== Gen loss: 2.8148
# Epoch: 63 ===== Batch: 0/235 ===== Disc loss: 0.6642 ===== Gen loss: 2.1811
# Epoch: 63 ===== Batch: 50/235 ===== Disc loss: 0.6672 ===== Gen loss: 2.5707
# Epoch: 63 ===== Batch: 100/235 ===== Disc loss: 0.6674 ===== Gen loss: 2.5948
# Epoch: 63 ===== Batch: 150/235 ===== Disc loss: 0.6979 ===== Gen loss: 2.6600
# Epoch: 63 ===== Batch: 200/235 ===== Disc loss: 1.2778 ===== Gen loss: 1.6379
# Epoch: 64 ===== Batch: 0/235 ===== Disc loss: 0.7101 ===== Gen loss: 2.8925
# Epoch: 64 ===== Batch: 50/235 ===== Disc loss: 0.6968 ===== Gen loss: 1.7147
# Epoch: 64 ===== Batch: 100/235 ===== Disc loss: 0.7328 ===== Gen loss: 2.8079
# Epoch: 64 ===== Batch: 150/235 ===== Disc loss: 0.6608 ===== Gen loss: 2.2777
# Epoch: 64 ===== Batch: 200/235 ===== Disc loss: 0.6600 ===== Gen loss: 2.2454
# Epoch: 65 ===== Batch: 0/235 ===== Disc loss: 0.6710 ===== Gen loss: 2.3598
# Epoch: 65 ===== Batch: 50/235 ===== Disc loss: 0.7297 ===== Gen loss: 2.1622
# Epoch: 65 ===== Batch: 100/235 ===== Disc loss: 0.6784 ===== Gen loss: 2.2956
# Epoch: 65 ===== Batch: 150/235 ===== Disc loss: 0.6583 ===== Gen loss: 2.3810
# Epoch: 65 ===== Batch: 200/235 ===== Disc loss: 0.6856 ===== Gen loss: 2.5121
# Epoch: 66 ===== Batch: 0/235 ===== Disc loss: 0.7072 ===== Gen loss: 2.1795
# Epoch: 66 ===== Batch: 50/235 ===== Disc loss: 0.6633 ===== Gen loss: 2.6868
# Epoch: 66 ===== Batch: 100/235 ===== Disc loss: 0.6604 ===== Gen loss: 2.1485
# Epoch: 66 ===== Batch: 150/235 ===== Disc loss: 0.6701 ===== Gen loss: 2.6999
# Epoch: 66 ===== Batch: 200/235 ===== Disc loss: 0.6577 ===== Gen loss: 2.3255
# Epoch: 67 ===== Batch: 0/235 ===== Disc loss: 0.6623 ===== Gen loss: 2.2616
# Epoch: 67 ===== Batch: 50/235 ===== Disc loss: 0.6611 ===== Gen loss: 2.3955
# Epoch: 67 ===== Batch: 100/235 ===== Disc loss: 0.9500 ===== Gen loss: 2.4209
# Epoch: 67 ===== Batch: 150/235 ===== Disc loss: 0.6672 ===== Gen loss: 2.4984
# Epoch: 67 ===== Batch: 200/235 ===== Disc loss: 0.6661 ===== Gen loss: 2.0786
# Epoch: 68 ===== Batch: 0/235 ===== Disc loss: 0.6681 ===== Gen loss: 2.4335
# Epoch: 68 ===== Batch: 50/235 ===== Disc loss: 0.6635 ===== Gen loss: 2.2880
# Epoch: 68 ===== Batch: 100/235 ===== Disc loss: 0.7037 ===== Gen loss: 3.3078
# Epoch: 68 ===== Batch: 150/235 ===== Disc loss: 0.6626 ===== Gen loss: 2.4709
# Epoch: 68 ===== Batch: 200/235 ===== Disc loss: 0.7901 ===== Gen loss: 1.3330
# Epoch: 69 ===== Batch: 0/235 ===== Disc loss: 0.6621 ===== Gen loss: 2.4103
# Epoch: 69 ===== Batch: 50/235 ===== Disc loss: 0.6651 ===== Gen loss: 2.0687
# Epoch: 69 ===== Batch: 100/235 ===== Disc loss: 0.6654 ===== Gen loss: 2.6205
# Epoch: 69 ===== Batch: 150/235 ===== Disc loss: 0.6613 ===== Gen loss: 2.1444
# Epoch: 69 ===== Batch: 200/235 ===== Disc loss: 0.7130 ===== Gen loss: 1.9171
# Epoch: 70 ===== Batch: 0/235 ===== Disc loss: 0.7300 ===== Gen loss: 2.9797
# Epoch: 70 ===== Batch: 50/235 ===== Disc loss: 0.6580 ===== Gen loss: 2.3729
# Epoch: 70 ===== Batch: 100/235 ===== Disc loss: 0.6752 ===== Gen loss: 2.2613
# Epoch: 70 ===== Batch: 150/235 ===== Disc loss: 0.6761 ===== Gen loss: 2.5859
# Epoch: 70 ===== Batch: 200/235 ===== Disc loss: 0.6725 ===== Gen loss: 2.6181
# Epoch: 71 ===== Batch: 0/235 ===== Disc loss: 0.8314 ===== Gen loss: 1.9740
# Epoch: 71 ===== Batch: 50/235 ===== Disc loss: 0.7074 ===== Gen loss: 1.6014
# Epoch: 71 ===== Batch: 100/235 ===== Disc loss: 0.6625 ===== Gen loss: 2.3471
# Epoch: 71 ===== Batch: 150/235 ===== Disc loss: 0.6816 ===== Gen loss: 2.1159
# Epoch: 71 ===== Batch: 200/235 ===== Disc loss: 0.6961 ===== Gen loss: 2.8720
# Epoch: 72 ===== Batch: 0/235 ===== Disc loss: 0.6699 ===== Gen loss: 2.2376
# Epoch: 72 ===== Batch: 50/235 ===== Disc loss: 0.6587 ===== Gen loss: 2.3802
# Epoch: 72 ===== Batch: 100/235 ===== Disc loss: 0.6836 ===== Gen loss: 2.1713
# Epoch: 72 ===== Batch: 150/235 ===== Disc loss: 0.6695 ===== Gen loss: 2.6992
# Epoch: 72 ===== Batch: 200/235 ===== Disc loss: 0.6583 ===== Gen loss: 2.2851
# Epoch: 73 ===== Batch: 0/235 ===== Disc loss: 0.6595 ===== Gen loss: 2.5283
# Epoch: 73 ===== Batch: 50/235 ===== Disc loss: 0.6646 ===== Gen loss: 2.5289
# Epoch: 73 ===== Batch: 100/235 ===== Disc loss: 0.6650 ===== Gen loss: 2.2662
# Epoch: 73 ===== Batch: 150/235 ===== Disc loss: 0.7122 ===== Gen loss: 1.9495
# Epoch: 73 ===== Batch: 200/235 ===== Disc loss: 0.7290 ===== Gen loss: 1.8944
# Epoch: 74 ===== Batch: 0/235 ===== Disc loss: 0.6785 ===== Gen loss: 1.9137
# Epoch: 74 ===== Batch: 50/235 ===== Disc loss: 0.6606 ===== Gen loss: 2.5687
# Epoch: 74 ===== Batch: 100/235 ===== Disc loss: 0.6856 ===== Gen loss: 1.9319
# Epoch: 74 ===== Batch: 150/235 ===== Disc loss: 0.7634 ===== Gen loss: 2.3771
# Epoch: 74 ===== Batch: 200/235 ===== Disc loss: 0.7164 ===== Gen loss: 2.1050
# Epoch: 75 ===== Batch: 0/235 ===== Disc loss: 0.7236 ===== Gen loss: 1.5935
# Epoch: 75 ===== Batch: 50/235 ===== Disc loss: 0.7381 ===== Gen loss: 2.7452
# Epoch: 75 ===== Batch: 100/235 ===== Disc loss: 0.6629 ===== Gen loss: 2.5771
# Epoch: 75 ===== Batch: 150/235 ===== Disc loss: 0.6715 ===== Gen loss: 2.5897
# Epoch: 75 ===== Batch: 200/235 ===== Disc loss: 0.6611 ===== Gen loss: 2.2622
# Epoch: 76 ===== Batch: 0/235 ===== Disc loss: 0.6823 ===== Gen loss: 2.7433
# Epoch: 76 ===== Batch: 50/235 ===== Disc loss: 0.6635 ===== Gen loss: 2.3765
# Epoch: 76 ===== Batch: 100/235 ===== Disc loss: 0.6654 ===== Gen loss: 2.2913
# Epoch: 76 ===== Batch: 150/235 ===== Disc loss: 0.6958 ===== Gen loss: 2.8873
# Epoch: 76 ===== Batch: 200/235 ===== Disc loss: 0.6642 ===== Gen loss: 2.5756
# Epoch: 77 ===== Batch: 0/235 ===== Disc loss: 0.6765 ===== Gen loss: 2.3562
# Epoch: 77 ===== Batch: 50/235 ===== Disc loss: 0.6859 ===== Gen loss: 2.6528
# Epoch: 77 ===== Batch: 100/235 ===== Disc loss: 0.7002 ===== Gen loss: 1.9271
# Epoch: 77 ===== Batch: 150/235 ===== Disc loss: 0.6640 ===== Gen loss: 2.6168
# Epoch: 77 ===== Batch: 200/235 ===== Disc loss: 0.6631 ===== Gen loss: 2.4869
# Epoch: 78 ===== Batch: 0/235 ===== Disc loss: 0.7435 ===== Gen loss: 2.8122
# Epoch: 78 ===== Batch: 50/235 ===== Disc loss: 0.6774 ===== Gen loss: 2.6555
# Epoch: 78 ===== Batch: 100/235 ===== Disc loss: 0.6800 ===== Gen loss: 2.5906
# Epoch: 78 ===== Batch: 150/235 ===== Disc loss: 0.6752 ===== Gen loss: 2.7800
# Epoch: 78 ===== Batch: 200/235 ===== Disc loss: 0.6600 ===== Gen loss: 1.9180
# Epoch: 79 ===== Batch: 0/235 ===== Disc loss: 0.6584 ===== Gen loss: 2.1363
# Epoch: 79 ===== Batch: 50/235 ===== Disc loss: 0.6604 ===== Gen loss: 2.4930
# Epoch: 79 ===== Batch: 100/235 ===== Disc loss: 0.6633 ===== Gen loss: 2.2583
# Epoch: 79 ===== Batch: 150/235 ===== Disc loss: 1.0406 ===== Gen loss: 2.2994
# Epoch: 79 ===== Batch: 200/235 ===== Disc loss: 0.6709 ===== Gen loss: 1.8131
# Epoch: 80 ===== Batch: 0/235 ===== Disc loss: 0.6706 ===== Gen loss: 2.2514
# Epoch: 80 ===== Batch: 50/235 ===== Disc loss: 0.6646 ===== Gen loss: 2.5621
# Epoch: 80 ===== Batch: 100/235 ===== Disc loss: 0.6666 ===== Gen loss: 2.1511
# Epoch: 80 ===== Batch: 150/235 ===== Disc loss: 0.7044 ===== Gen loss: 2.0613
# Epoch: 80 ===== Batch: 200/235 ===== Disc loss: 0.6657 ===== Gen loss: 2.3469
# Epoch: 81 ===== Batch: 0/235 ===== Disc loss: 0.7894 ===== Gen loss: 4.0881
# Epoch: 81 ===== Batch: 50/235 ===== Disc loss: 0.6609 ===== Gen loss: 2.2527
# Epoch: 81 ===== Batch: 100/235 ===== Disc loss: 0.6676 ===== Gen loss: 2.7261
# Epoch: 81 ===== Batch: 150/235 ===== Disc loss: 0.6662 ===== Gen loss: 2.4199
# Epoch: 81 ===== Batch: 200/235 ===== Disc loss: 0.6711 ===== Gen loss: 2.7026
# Epoch: 82 ===== Batch: 0/235 ===== Disc loss: 0.7156 ===== Gen loss: 1.8654
# Epoch: 82 ===== Batch: 50/235 ===== Disc loss: 0.6617 ===== Gen loss: 2.4388
# Epoch: 82 ===== Batch: 100/235 ===== Disc loss: 0.6611 ===== Gen loss: 2.7378
# Epoch: 82 ===== Batch: 150/235 ===== Disc loss: 0.6631 ===== Gen loss: 2.4248
# Epoch: 82 ===== Batch: 200/235 ===== Disc loss: 0.6674 ===== Gen loss: 2.5230
# Epoch: 83 ===== Batch: 0/235 ===== Disc loss: 0.6744 ===== Gen loss: 1.6826
# Epoch: 83 ===== Batch: 50/235 ===== Disc loss: 0.6685 ===== Gen loss: 2.5462
# Epoch: 83 ===== Batch: 100/235 ===== Disc loss: 0.6633 ===== Gen loss: 2.2022
# Epoch: 83 ===== Batch: 150/235 ===== Disc loss: 0.6645 ===== Gen loss: 2.0959
# Epoch: 83 ===== Batch: 200/235 ===== Disc loss: 1.0531 ===== Gen loss: 1.0035
# Epoch: 84 ===== Batch: 0/235 ===== Disc loss: 0.7548 ===== Gen loss: 3.5731
# Epoch: 84 ===== Batch: 50/235 ===== Disc loss: 0.7249 ===== Gen loss: 2.4262
# Epoch: 84 ===== Batch: 100/235 ===== Disc loss: 0.6617 ===== Gen loss: 2.3294
# Epoch: 84 ===== Batch: 150/235 ===== Disc loss: 0.6615 ===== Gen loss: 2.4671
# Epoch: 84 ===== Batch: 200/235 ===== Disc loss: 0.6641 ===== Gen loss: 2.1982
# Epoch: 85 ===== Batch: 0/235 ===== Disc loss: 0.6587 ===== Gen loss: 2.2442
# Epoch: 85 ===== Batch: 50/235 ===== Disc loss: 0.6603 ===== Gen loss: 2.4820
# Epoch: 85 ===== Batch: 100/235 ===== Disc loss: 0.6642 ===== Gen loss: 2.2186
# Epoch: 85 ===== Batch: 150/235 ===== Disc loss: 0.6760 ===== Gen loss: 2.6675
# Epoch: 85 ===== Batch: 200/235 ===== Disc loss: 0.6659 ===== Gen loss: 2.1793
# Epoch: 86 ===== Batch: 0/235 ===== Disc loss: 0.6602 ===== Gen loss: 2.2392
# Epoch: 86 ===== Batch: 50/235 ===== Disc loss: 0.6619 ===== Gen loss: 2.2737
# Epoch: 86 ===== Batch: 100/235 ===== Disc loss: 0.6635 ===== Gen loss: 2.2936
# Epoch: 86 ===== Batch: 150/235 ===== Disc loss: 0.6622 ===== Gen loss: 2.4113
# Epoch: 86 ===== Batch: 200/235 ===== Disc loss: 0.6764 ===== Gen loss: 2.2951
# Epoch: 87 ===== Batch: 0/235 ===== Disc loss: 0.6793 ===== Gen loss: 2.3302
# Epoch: 87 ===== Batch: 50/235 ===== Disc loss: 0.6564 ===== Gen loss: 2.5488
# Epoch: 87 ===== Batch: 100/235 ===== Disc loss: 0.6761 ===== Gen loss: 2.0514
# Epoch: 87 ===== Batch: 150/235 ===== Disc loss: 0.6690 ===== Gen loss: 2.2881
# Epoch: 87 ===== Batch: 200/235 ===== Disc loss: 0.6690 ===== Gen loss: 2.2356
# Epoch: 88 ===== Batch: 0/235 ===== Disc loss: 0.6594 ===== Gen loss: 1.9933
# Epoch: 88 ===== Batch: 50/235 ===== Disc loss: 0.6603 ===== Gen loss: 2.6243
# Epoch: 88 ===== Batch: 100/235 ===== Disc loss: 0.6816 ===== Gen loss: 2.1749
# Epoch: 88 ===== Batch: 150/235 ===== Disc loss: 0.6601 ===== Gen loss: 2.3933
# Epoch: 88 ===== Batch: 200/235 ===== Disc loss: 0.6735 ===== Gen loss: 2.1658
# Epoch: 89 ===== Batch: 0/235 ===== Disc loss: 0.8836 ===== Gen loss: 1.5904
# Epoch: 89 ===== Batch: 50/235 ===== Disc loss: 0.6943 ===== Gen loss: 2.3605
# Epoch: 89 ===== Batch: 100/235 ===== Disc loss: 0.7089 ===== Gen loss: 2.5941
# Epoch: 89 ===== Batch: 150/235 ===== Disc loss: 0.6669 ===== Gen loss: 2.1032
# Epoch: 89 ===== Batch: 200/235 ===== Disc loss: 0.7611 ===== Gen loss: 2.0131
# Epoch: 90 ===== Batch: 0/235 ===== Disc loss: 0.7039 ===== Gen loss: 2.3878
# Epoch: 90 ===== Batch: 50/235 ===== Disc loss: 0.6633 ===== Gen loss: 2.2997
# Epoch: 90 ===== Batch: 100/235 ===== Disc loss: 0.6637 ===== Gen loss: 2.6245
# Epoch: 90 ===== Batch: 150/235 ===== Disc loss: 0.6809 ===== Gen loss: 2.8461
# Epoch: 90 ===== Batch: 200/235 ===== Disc loss: 0.7302 ===== Gen loss: 3.1164
# Epoch: 91 ===== Batch: 0/235 ===== Disc loss: 0.9138 ===== Gen loss: 3.7579
# Epoch: 91 ===== Batch: 50/235 ===== Disc loss: 0.7385 ===== Gen loss: 1.5523
# Epoch: 91 ===== Batch: 100/235 ===== Disc loss: 0.6742 ===== Gen loss: 2.0761
# Epoch: 91 ===== Batch: 150/235 ===== Disc loss: 0.6629 ===== Gen loss: 2.6012
# Epoch: 91 ===== Batch: 200/235 ===== Disc loss: 0.6651 ===== Gen loss: 2.3806
# Epoch: 92 ===== Batch: 0/235 ===== Disc loss: 0.9674 ===== Gen loss: 4.3285
# Epoch: 92 ===== Batch: 50/235 ===== Disc loss: 0.6577 ===== Gen loss: 2.3366
# Epoch: 92 ===== Batch: 100/235 ===== Disc loss: 0.6712 ===== Gen loss: 2.6361
# Epoch: 92 ===== Batch: 150/235 ===== Disc loss: 0.7278 ===== Gen loss: 1.4282
# Epoch: 92 ===== Batch: 200/235 ===== Disc loss: 0.6599 ===== Gen loss: 2.3045
# Epoch: 93 ===== Batch: 0/235 ===== Disc loss: 0.6612 ===== Gen loss: 1.8837
# Epoch: 93 ===== Batch: 50/235 ===== Disc loss: 0.6585 ===== Gen loss: 2.3139
# Epoch: 93 ===== Batch: 100/235 ===== Disc loss: 0.6677 ===== Gen loss: 2.1128
# Epoch: 93 ===== Batch: 150/235 ===== Disc loss: 0.6649 ===== Gen loss: 2.6162
# Epoch: 93 ===== Batch: 200/235 ===== Disc loss: 0.6590 ===== Gen loss: 2.3841
# Epoch: 94 ===== Batch: 0/235 ===== Disc loss: 0.7092 ===== Gen loss: 2.1718
# Epoch: 94 ===== Batch: 50/235 ===== Disc loss: 0.6612 ===== Gen loss: 2.7203
# Epoch: 94 ===== Batch: 100/235 ===== Disc loss: 0.7328 ===== Gen loss: 2.4350
# Epoch: 94 ===== Batch: 150/235 ===== Disc loss: 0.6718 ===== Gen loss: 1.7656
# Epoch: 94 ===== Batch: 200/235 ===== Disc loss: 0.6629 ===== Gen loss: 2.1955
# Epoch: 95 ===== Batch: 0/235 ===== Disc loss: 0.6616 ===== Gen loss: 2.2843
# Epoch: 95 ===== Batch: 50/235 ===== Disc loss: 0.7634 ===== Gen loss: 3.6595
# Epoch: 95 ===== Batch: 100/235 ===== Disc loss: 0.6595 ===== Gen loss: 2.3361
# Epoch: 95 ===== Batch: 150/235 ===== Disc loss: 0.6741 ===== Gen loss: 2.4178
# Epoch: 95 ===== Batch: 200/235 ===== Disc loss: 0.6889 ===== Gen loss: 2.2477
# Epoch: 96 ===== Batch: 0/235 ===== Disc loss: 0.6673 ===== Gen loss: 2.7227
# Epoch: 96 ===== Batch: 50/235 ===== Disc loss: 0.8127 ===== Gen loss: 4.0722
# Epoch: 96 ===== Batch: 100/235 ===== Disc loss: 0.6945 ===== Gen loss: 2.2947
# Epoch: 96 ===== Batch: 150/235 ===== Disc loss: 0.6822 ===== Gen loss: 2.8443
# Epoch: 96 ===== Batch: 200/235 ===== Disc loss: 0.6605 ===== Gen loss: 2.5116
# Epoch: 97 ===== Batch: 0/235 ===== Disc loss: 0.7509 ===== Gen loss: 2.4785
# Epoch: 97 ===== Batch: 50/235 ===== Disc loss: 0.7087 ===== Gen loss: 1.4358
# Epoch: 97 ===== Batch: 100/235 ===== Disc loss: 0.6620 ===== Gen loss: 2.3305
# Epoch: 97 ===== Batch: 150/235 ===== Disc loss: 0.6644 ===== Gen loss: 2.5336
# Epoch: 97 ===== Batch: 200/235 ===== Disc loss: 0.6628 ===== Gen loss: 2.2427
# Epoch: 98 ===== Batch: 0/235 ===== Disc loss: 0.7482 ===== Gen loss: 3.2871
# Epoch: 98 ===== Batch: 50/235 ===== Disc loss: 0.6704 ===== Gen loss: 2.4246
# Epoch: 98 ===== Batch: 100/235 ===== Disc loss: 0.6680 ===== Gen loss: 2.7623
# Epoch: 98 ===== Batch: 150/235 ===== Disc loss: 0.6744 ===== Gen loss: 2.9709
# Epoch: 98 ===== Batch: 200/235 ===== Disc loss: 0.7206 ===== Gen loss: 3.1300
# Epoch: 99 ===== Batch: 0/235 ===== Disc loss: 0.6709 ===== Gen loss: 2.3214
# Epoch: 99 ===== Batch: 50/235 ===== Disc loss: 0.6609 ===== Gen loss: 2.6745
# Epoch: 99 ===== Batch: 100/235 ===== Disc loss: 0.6609 ===== Gen loss: 2.5551
# Epoch: 99 ===== Batch: 150/235 ===== Disc loss: 0.7385 ===== Gen loss: 2.3366
# Epoch: 99 ===== Batch: 200/235 ===== Disc loss: 0.6718 ===== Gen loss: 2.5659
# Epoch: 100 ===== Batch: 0/235 ===== Disc loss: 0.6756 ===== Gen loss: 2.4060
# Epoch: 100 ===== Batch: 50/235 ===== Disc loss: 0.6912 ===== Gen loss: 2.3802
# Epoch: 100 ===== Batch: 100/235 ===== Disc loss: 0.6647 ===== Gen loss: 2.0872
# Epoch: 100 ===== Batch: 150/235 ===== Disc loss: 0.6585 ===== Gen loss: 2.3131
# Epoch: 100 ===== Batch: 200/235 ===== Disc loss: 0.6574 ===== Gen loss: 2.4965
# Epoch: 101 ===== Batch: 0/235 ===== Disc loss: 0.6660 ===== Gen loss: 2.3367
# Epoch: 101 ===== Batch: 50/235 ===== Disc loss: 0.6935 ===== Gen loss: 2.9026
# Epoch: 101 ===== Batch: 100/235 ===== Disc loss: 0.8891 ===== Gen loss: 1.4478
# Epoch: 101 ===== Batch: 150/235 ===== Disc loss: 0.6756 ===== Gen loss: 2.1985
# Epoch: 101 ===== Batch: 200/235 ===== Disc loss: 0.7386 ===== Gen loss: 1.7337
# Epoch: 102 ===== Batch: 0/235 ===== Disc loss: 0.6614 ===== Gen loss: 2.0767
# Epoch: 102 ===== Batch: 50/235 ===== Disc loss: 0.8358 ===== Gen loss: 1.6440
# Epoch: 102 ===== Batch: 100/235 ===== Disc loss: 0.6705 ===== Gen loss: 2.3854
# Epoch: 102 ===== Batch: 150/235 ===== Disc loss: 0.7431 ===== Gen loss: 3.2088
# Epoch: 102 ===== Batch: 200/235 ===== Disc loss: 0.6834 ===== Gen loss: 1.8441
# Epoch: 103 ===== Batch: 0/235 ===== Disc loss: 0.6648 ===== Gen loss: 2.3188
# Epoch: 103 ===== Batch: 50/235 ===== Disc loss: 0.6688 ===== Gen loss: 2.4750
# Epoch: 103 ===== Batch: 100/235 ===== Disc loss: 0.7003 ===== Gen loss: 1.7979
# Epoch: 103 ===== Batch: 150/235 ===== Disc loss: 0.7446 ===== Gen loss: 3.4355
# Epoch: 103 ===== Batch: 200/235 ===== Disc loss: 0.6706 ===== Gen loss: 2.0755
# Epoch: 104 ===== Batch: 0/235 ===== Disc loss: 0.6677 ===== Gen loss: 2.0815
# Epoch: 104 ===== Batch: 50/235 ===== Disc loss: 0.7668 ===== Gen loss: 3.4043
# Epoch: 104 ===== Batch: 100/235 ===== Disc loss: 0.6864 ===== Gen loss: 2.6843
# Epoch: 104 ===== Batch: 150/235 ===== Disc loss: 0.6595 ===== Gen loss: 2.2209
# Epoch: 104 ===== Batch: 200/235 ===== Disc loss: 0.6785 ===== Gen loss: 1.8993
# Epoch: 105 ===== Batch: 0/235 ===== Disc loss: 0.6615 ===== Gen loss: 2.2834
# Epoch: 105 ===== Batch: 50/235 ===== Disc loss: 0.6621 ===== Gen loss: 2.5808
# Epoch: 105 ===== Batch: 100/235 ===== Disc loss: 0.6718 ===== Gen loss: 2.4659
# Epoch: 105 ===== Batch: 150/235 ===== Disc loss: 0.7187 ===== Gen loss: 1.8024
# Epoch: 105 ===== Batch: 200/235 ===== Disc loss: 0.6588 ===== Gen loss: 2.2635
# Epoch: 106 ===== Batch: 0/235 ===== Disc loss: 0.6732 ===== Gen loss: 2.5202
# Epoch: 106 ===== Batch: 50/235 ===== Disc loss: 0.7294 ===== Gen loss: 2.0722
# Epoch: 106 ===== Batch: 100/235 ===== Disc loss: 0.7004 ===== Gen loss: 1.8839
# Epoch: 106 ===== Batch: 150/235 ===== Disc loss: 0.6686 ===== Gen loss: 2.0796
# Epoch: 106 ===== Batch: 200/235 ===== Disc loss: 0.8539 ===== Gen loss: 2.1742
# Epoch: 107 ===== Batch: 0/235 ===== Disc loss: 0.6742 ===== Gen loss: 2.5668
# Epoch: 107 ===== Batch: 50/235 ===== Disc loss: 0.6661 ===== Gen loss: 2.4414
# Epoch: 107 ===== Batch: 100/235 ===== Disc loss: 0.6733 ===== Gen loss: 2.1194
# Epoch: 107 ===== Batch: 150/235 ===== Disc loss: 0.6670 ===== Gen loss: 2.4517
# Epoch: 107 ===== Batch: 200/235 ===== Disc loss: 0.6752 ===== Gen loss: 2.4890
# Epoch: 108 ===== Batch: 0/235 ===== Disc loss: 0.6802 ===== Gen loss: 2.6848
# Epoch: 108 ===== Batch: 50/235 ===== Disc loss: 0.6663 ===== Gen loss: 2.6940
# Epoch: 108 ===== Batch: 100/235 ===== Disc loss: 0.6637 ===== Gen loss: 1.9070
# Epoch: 108 ===== Batch: 150/235 ===== Disc loss: 0.6585 ===== Gen loss: 2.4761
# Epoch: 108 ===== Batch: 200/235 ===== Disc loss: 0.6569 ===== Gen loss: 2.5320
# Epoch: 109 ===== Batch: 0/235 ===== Disc loss: 0.6623 ===== Gen loss: 2.2555
# Epoch: 109 ===== Batch: 50/235 ===== Disc loss: 0.6593 ===== Gen loss: 2.5421
# Epoch: 109 ===== Batch: 100/235 ===== Disc loss: 0.6647 ===== Gen loss: 2.0067
# Epoch: 109 ===== Batch: 150/235 ===== Disc loss: 0.6597 ===== Gen loss: 2.5093
# Epoch: 109 ===== Batch: 200/235 ===== Disc loss: 0.6611 ===== Gen loss: 2.6401
# Epoch: 110 ===== Batch: 0/235 ===== Disc loss: 0.6573 ===== Gen loss: 2.5026
# Epoch: 110 ===== Batch: 50/235 ===== Disc loss: 0.6602 ===== Gen loss: 2.6070
# Epoch: 110 ===== Batch: 100/235 ===== Disc loss: 3.2631 ===== Gen loss: 0.3983
# Epoch: 110 ===== Batch: 150/235 ===== Disc loss: 0.7338 ===== Gen loss: 1.7805
# Epoch: 110 ===== Batch: 200/235 ===== Disc loss: 0.6669 ===== Gen loss: 2.5502
# Epoch: 111 ===== Batch: 0/235 ===== Disc loss: 0.6691 ===== Gen loss: 2.5369
# Epoch: 111 ===== Batch: 50/235 ===== Disc loss: 0.6677 ===== Gen loss: 2.5749
# Epoch: 111 ===== Batch: 100/235 ===== Disc loss: 0.6686 ===== Gen loss: 2.8402
# Epoch: 111 ===== Batch: 150/235 ===== Disc loss: 0.6677 ===== Gen loss: 2.0330
# Epoch: 111 ===== Batch: 200/235 ===== Disc loss: 0.6632 ===== Gen loss: 2.4041
# Epoch: 112 ===== Batch: 0/235 ===== Disc loss: 0.6608 ===== Gen loss: 2.5316
# Epoch: 112 ===== Batch: 50/235 ===== Disc loss: 0.6968 ===== Gen loss: 2.7939
# Epoch: 112 ===== Batch: 100/235 ===== Disc loss: 0.6646 ===== Gen loss: 2.3459
# Epoch: 112 ===== Batch: 150/235 ===== Disc loss: 0.7352 ===== Gen loss: 2.6872
# Epoch: 112 ===== Batch: 200/235 ===== Disc loss: 0.6600 ===== Gen loss: 2.2765
# Epoch: 113 ===== Batch: 0/235 ===== Disc loss: 0.6652 ===== Gen loss: 2.3432
# Epoch: 113 ===== Batch: 50/235 ===== Disc loss: 0.6691 ===== Gen loss: 2.3474
# Epoch: 113 ===== Batch: 100/235 ===== Disc loss: 0.6905 ===== Gen loss: 2.1574
# Epoch: 113 ===== Batch: 150/235 ===== Disc loss: 0.6773 ===== Gen loss: 2.6946
# Epoch: 113 ===== Batch: 200/235 ===== Disc loss: 0.6566 ===== Gen loss: 2.3459
# Epoch: 114 ===== Batch: 0/235 ===== Disc loss: 0.6590 ===== Gen loss: 2.2578
# Epoch: 114 ===== Batch: 50/235 ===== Disc loss: 0.6623 ===== Gen loss: 2.3017
# Epoch: 114 ===== Batch: 100/235 ===== Disc loss: 0.6685 ===== Gen loss: 2.2515
# Epoch: 114 ===== Batch: 150/235 ===== Disc loss: 0.6655 ===== Gen loss: 1.9524
# Epoch: 114 ===== Batch: 200/235 ===== Disc loss: 0.6580 ===== Gen loss: 2.5824
# Epoch: 115 ===== Batch: 0/235 ===== Disc loss: 0.6991 ===== Gen loss: 2.0189
# Epoch: 115 ===== Batch: 50/235 ===== Disc loss: 0.6990 ===== Gen loss: 2.0503
# Epoch: 115 ===== Batch: 100/235 ===== Disc loss: 0.6621 ===== Gen loss: 2.1350
# Epoch: 115 ===== Batch: 150/235 ===== Disc loss: 0.6620 ===== Gen loss: 2.3766
# Epoch: 115 ===== Batch: 200/235 ===== Disc loss: 0.6584 ===== Gen loss: 2.3487
# Epoch: 116 ===== Batch: 0/235 ===== Disc loss: 0.6652 ===== Gen loss: 2.1697
# Epoch: 116 ===== Batch: 50/235 ===== Disc loss: 0.6719 ===== Gen loss: 2.1786
# Epoch: 116 ===== Batch: 100/235 ===== Disc loss: 0.6911 ===== Gen loss: 2.7974
# Epoch: 116 ===== Batch: 150/235 ===== Disc loss: 0.6729 ===== Gen loss: 2.5435
# Epoch: 116 ===== Batch: 200/235 ===== Disc loss: 0.6718 ===== Gen loss: 2.4892
# Epoch: 117 ===== Batch: 0/235 ===== Disc loss: 0.6638 ===== Gen loss: 2.2405
# Epoch: 117 ===== Batch: 50/235 ===== Disc loss: 0.6557 ===== Gen loss: 2.3905
# Epoch: 117 ===== Batch: 100/235 ===== Disc loss: 0.6765 ===== Gen loss: 2.2785
# Epoch: 117 ===== Batch: 150/235 ===== Disc loss: 0.8255 ===== Gen loss: 1.2153
# Epoch: 117 ===== Batch: 200/235 ===== Disc loss: 0.6918 ===== Gen loss: 2.4405
# Epoch: 118 ===== Batch: 0/235 ===== Disc loss: 0.6855 ===== Gen loss: 2.0907
# Epoch: 118 ===== Batch: 50/235 ===== Disc loss: 0.7218 ===== Gen loss: 3.0819
# Epoch: 118 ===== Batch: 100/235 ===== Disc loss: 0.6693 ===== Gen loss: 2.0817
# Epoch: 118 ===== Batch: 150/235 ===== Disc loss: 0.6712 ===== Gen loss: 2.1959
# Epoch: 118 ===== Batch: 200/235 ===== Disc loss: 0.6979 ===== Gen loss: 1.3974
# Epoch: 119 ===== Batch: 0/235 ===== Disc loss: 0.6621 ===== Gen loss: 2.4781
# Epoch: 119 ===== Batch: 50/235 ===== Disc loss: 0.6585 ===== Gen loss: 2.3047
# Epoch: 119 ===== Batch: 100/235 ===== Disc loss: 0.6931 ===== Gen loss: 1.7968
# Epoch: 119 ===== Batch: 150/235 ===== Disc loss: 0.6622 ===== Gen loss: 2.3737
# Epoch: 119 ===== Batch: 200/235 ===== Disc loss: 0.6761 ===== Gen loss: 2.3039
# Epoch: 120 ===== Batch: 0/235 ===== Disc loss: 0.6592 ===== Gen loss: 2.1937
# Epoch: 120 ===== Batch: 50/235 ===== Disc loss: 0.6862 ===== Gen loss: 2.8693
# Epoch: 120 ===== Batch: 100/235 ===== Disc loss: 0.6705 ===== Gen loss: 2.5398
# Epoch: 120 ===== Batch: 150/235 ===== Disc loss: 0.6754 ===== Gen loss: 2.7369
# Epoch: 120 ===== Batch: 200/235 ===== Disc loss: 0.6700 ===== Gen loss: 2.2449
# Epoch: 121 ===== Batch: 0/235 ===== Disc loss: 0.6735 ===== Gen loss: 2.6199
# Epoch: 121 ===== Batch: 50/235 ===== Disc loss: 0.6644 ===== Gen loss: 2.3751
# Epoch: 121 ===== Batch: 100/235 ===== Disc loss: 0.7081 ===== Gen loss: 1.5054
# Epoch: 121 ===== Batch: 150/235 ===== Disc loss: 0.6648 ===== Gen loss: 2.2596
# Epoch: 121 ===== Batch: 200/235 ===== Disc loss: 0.9345 ===== Gen loss: 4.0186
# Epoch: 122 ===== Batch: 0/235 ===== Disc loss: 0.6595 ===== Gen loss: 2.5094
# Epoch: 122 ===== Batch: 50/235 ===== Disc loss: 0.6686 ===== Gen loss: 2.2199
# Epoch: 122 ===== Batch: 100/235 ===== Disc loss: 0.6608 ===== Gen loss: 2.4657
# Epoch: 122 ===== Batch: 150/235 ===== Disc loss: 0.6631 ===== Gen loss: 2.6383
# Epoch: 122 ===== Batch: 200/235 ===== Disc loss: 0.6676 ===== Gen loss: 2.7394
# Epoch: 123 ===== Batch: 0/235 ===== Disc loss: 0.6873 ===== Gen loss: 2.4777
# Epoch: 123 ===== Batch: 50/235 ===== Disc loss: 0.6635 ===== Gen loss: 2.1117
# Epoch: 123 ===== Batch: 100/235 ===== Disc loss: 0.6804 ===== Gen loss: 2.5990
# Epoch: 123 ===== Batch: 150/235 ===== Disc loss: 0.6710 ===== Gen loss: 2.5584
# ...
# Epoch: 959 ===== Batch: 50/235 ===== Disc loss: 0.6514 ===== Gen loss: 2.2464
# Epoch: 959 ===== Batch: 100/235 ===== Disc loss: 0.6523 ===== Gen loss: 2.5179
# Epoch: 959 ===== Batch: 150/235 ===== Disc loss: 0.6516 ===== Gen loss: 2.3246
# Epoch: 959 ===== Batch: 200/235 ===== Disc loss: 0.6523 ===== Gen loss: 2.2300
# Epoch: 960 ===== Batch: 0/235 ===== Disc loss: 0.6515 ===== Gen loss: 2.3085
# Epoch: 960 ===== Batch: 50/235 ===== Disc loss: 0.6717 ===== Gen loss: 2.3401
# Epoch: 960 ===== Batch: 100/235 ===== Disc loss: 0.6557 ===== Gen loss: 2.4026
# Epoch: 960 ===== Batch: 150/235 ===== Disc loss: 0.6517 ===== Gen loss: 2.3479
# Epoch: 960 ===== Batch: 200/235 ===== Disc loss: 0.6523 ===== Gen loss: 2.3202
# Epoch: 961 ===== Batch: 0/235 ===== Disc loss: 0.6555 ===== Gen loss: 2.4089
# Epoch: 961 ===== Batch: 50/235 ===== Disc loss: 0.6569 ===== Gen loss: 2.2980
# Epoch: 961 ===== Batch: 100/235 ===== Disc loss: 0.6533 ===== Gen loss: 2.2307
# Epoch: 961 ===== Batch: 150/235 ===== Disc loss: 0.6515 ===== Gen loss: 2.3674
# Epoch: 961 ===== Batch: 200/235 ===== Disc loss: 0.6541 ===== Gen loss: 2.3258
# Epoch: 962 ===== Batch: 0/235 ===== Disc loss: 0.6514 ===== Gen loss: 2.2980
# Epoch: 962 ===== Batch: 50/235 ===== Disc loss: 0.6521 ===== Gen loss: 2.3464
# Epoch: 962 ===== Batch: 100/235 ===== Disc loss: 0.6569 ===== Gen loss: 2.1452
# Epoch: 962 ===== Batch: 150/235 ===== Disc loss: 0.6528 ===== Gen loss: 2.2083
# Epoch: 962 ===== Batch: 200/235 ===== Disc loss: 0.6609 ===== Gen loss: 2.1886
# Epoch: 963 ===== Batch: 0/235 ===== Disc loss: 0.6735 ===== Gen loss: 2.5097
# Epoch: 963 ===== Batch: 50/235 ===== Disc loss: 0.6578 ===== Gen loss: 2.4310
# Epoch: 963 ===== Batch: 100/235 ===== Disc loss: 0.6533 ===== Gen loss: 2.1816
# Epoch: 963 ===== Batch: 150/235 ===== Disc loss: 0.6556 ===== Gen loss: 2.3012
# Epoch: 963 ===== Batch: 200/235 ===== Disc loss: 0.7001 ===== Gen loss: 2.8088
# Epoch: 964 ===== Batch: 0/235 ===== Disc loss: 0.6527 ===== Gen loss: 2.3521
# Epoch: 964 ===== Batch: 50/235 ===== Disc loss: 0.6519 ===== Gen loss: 2.2892
# Epoch: 964 ===== Batch: 100/235 ===== Disc loss: 0.6533 ===== Gen loss: 2.3627
# Epoch: 964 ===== Batch: 150/235 ===== Disc loss: 0.6532 ===== Gen loss: 2.3772
# Epoch: 964 ===== Batch: 200/235 ===== Disc loss: 0.6526 ===== Gen loss: 2.3611
# Epoch: 965 ===== Batch: 0/235 ===== Disc loss: 0.6574 ===== Gen loss: 2.3676
# Epoch: 965 ===== Batch: 50/235 ===== Disc loss: 0.6566 ===== Gen loss: 2.1142
# Epoch: 965 ===== Batch: 100/235 ===== Disc loss: 0.6522 ===== Gen loss: 2.3630
# Epoch: 965 ===== Batch: 150/235 ===== Disc loss: 0.6525 ===== Gen loss: 2.2456
# Epoch: 965 ===== Batch: 200/235 ===== Disc loss: 0.6511 ===== Gen loss: 2.3182
# Epoch: 966 ===== Batch: 0/235 ===== Disc loss: 0.6519 ===== Gen loss: 2.3222
# Epoch: 966 ===== Batch: 50/235 ===== Disc loss: 0.6512 ===== Gen loss: 2.3469
# Epoch: 966 ===== Batch: 100/235 ===== Disc loss: 0.6513 ===== Gen loss: 2.3329
# Epoch: 966 ===== Batch: 150/235 ===== Disc loss: 0.6528 ===== Gen loss: 2.3098
# Epoch: 966 ===== Batch: 200/235 ===== Disc loss: 0.6515 ===== Gen loss: 2.3046
# Epoch: 967 ===== Batch: 0/235 ===== Disc loss: 0.6534 ===== Gen loss: 2.3255
# Epoch: 967 ===== Batch: 50/235 ===== Disc loss: 0.6513 ===== Gen loss: 2.3944
# Epoch: 967 ===== Batch: 100/235 ===== Disc loss: 0.6522 ===== Gen loss: 2.3494
# Epoch: 967 ===== Batch: 150/235 ===== Disc loss: 0.6517 ===== Gen loss: 2.2673
# Epoch: 967 ===== Batch: 200/235 ===== Disc loss: 0.6526 ===== Gen loss: 2.3446
# Epoch: 968 ===== Batch: 0/235 ===== Disc loss: 0.6543 ===== Gen loss: 2.3360
# Epoch: 968 ===== Batch: 50/235 ===== Disc loss: 0.6517 ===== Gen loss: 2.2286
# Epoch: 968 ===== Batch: 100/235 ===== Disc loss: 0.6519 ===== Gen loss: 2.2135
# Epoch: 968 ===== Batch: 150/235 ===== Disc loss: 0.6520 ===== Gen loss: 2.3967
# Epoch: 968 ===== Batch: 200/235 ===== Disc loss: 0.6508 ===== Gen loss: 2.3203
# Epoch: 969 ===== Batch: 0/235 ===== Disc loss: 0.6516 ===== Gen loss: 2.1147
# Epoch: 969 ===== Batch: 50/235 ===== Disc loss: 0.6555 ===== Gen loss: 2.3303
# Epoch: 969 ===== Batch: 100/235 ===== Disc loss: 0.6550 ===== Gen loss: 2.2994
# Epoch: 969 ===== Batch: 150/235 ===== Disc loss: 0.6536 ===== Gen loss: 2.2398
# Epoch: 969 ===== Batch: 200/235 ===== Disc loss: 0.6522 ===== Gen loss: 2.2598
# Epoch: 970 ===== Batch: 0/235 ===== Disc loss: 0.6527 ===== Gen loss: 2.2739
# Epoch: 970 ===== Batch: 50/235 ===== Disc loss: 0.8777 ===== Gen loss: 0.7319
# Epoch: 970 ===== Batch: 100/235 ===== Disc loss: 0.6592 ===== Gen loss: 2.3033
# Epoch: 970 ===== Batch: 150/235 ===== Disc loss: 0.6908 ===== Gen loss: 2.2190
# Epoch: 970 ===== Batch: 200/235 ===== Disc loss: 0.6605 ===== Gen loss: 2.3899
# Epoch: 971 ===== Batch: 0/235 ===== Disc loss: 0.6569 ===== Gen loss: 2.0828
# Epoch: 971 ===== Batch: 50/235 ===== Disc loss: 0.6604 ===== Gen loss: 2.4076
# Epoch: 971 ===== Batch: 100/235 ===== Disc loss: 0.6552 ===== Gen loss: 2.2420
# Epoch: 971 ===== Batch: 150/235 ===== Disc loss: 0.6692 ===== Gen loss: 2.2666
# Epoch: 971 ===== Batch: 200/235 ===== Disc loss: 0.6551 ===== Gen loss: 2.3384
# Epoch: 972 ===== Batch: 0/235 ===== Disc loss: 0.6607 ===== Gen loss: 2.4564
# Epoch: 972 ===== Batch: 50/235 ===== Disc loss: 0.6540 ===== Gen loss: 2.3605
# Epoch: 972 ===== Batch: 100/235 ===== Disc loss: 0.6553 ===== Gen loss: 2.2952
# Epoch: 972 ===== Batch: 150/235 ===== Disc loss: 0.6645 ===== Gen loss: 2.5417
# Epoch: 972 ===== Batch: 200/235 ===== Disc loss: 0.6551 ===== Gen loss: 2.1469
# Epoch: 973 ===== Batch: 0/235 ===== Disc loss: 0.6556 ===== Gen loss: 2.4428
# Epoch: 973 ===== Batch: 50/235 ===== Disc loss: 0.6528 ===== Gen loss: 2.2720
# Epoch: 973 ===== Batch: 100/235 ===== Disc loss: 0.6531 ===== Gen loss: 2.3498
# Epoch: 973 ===== Batch: 150/235 ===== Disc loss: 0.6534 ===== Gen loss: 2.2789
# Epoch: 973 ===== Batch: 200/235 ===== Disc loss: 0.6539 ===== Gen loss: 2.2059
# Epoch: 974 ===== Batch: 0/235 ===== Disc loss: 0.6568 ===== Gen loss: 2.4170
# Epoch: 974 ===== Batch: 50/235 ===== Disc loss: 0.6529 ===== Gen loss: 2.4353
# Epoch: 974 ===== Batch: 100/235 ===== Disc loss: 0.6576 ===== Gen loss: 2.4001
# Epoch: 974 ===== Batch: 150/235 ===== Disc loss: 0.6529 ===== Gen loss: 2.3162
# Epoch: 974 ===== Batch: 200/235 ===== Disc loss: 0.6539 ===== Gen loss: 2.1332
# Epoch: 975 ===== Batch: 0/235 ===== Disc loss: 0.6530 ===== Gen loss: 2.3744
# Epoch: 975 ===== Batch: 50/235 ===== Disc loss: 0.6536 ===== Gen loss: 2.2493
# Epoch: 975 ===== Batch: 100/235 ===== Disc loss: 0.6573 ===== Gen loss: 2.3843
# Epoch: 975 ===== Batch: 150/235 ===== Disc loss: 0.6529 ===== Gen loss: 2.4452
# Epoch: 975 ===== Batch: 200/235 ===== Disc loss: 0.6624 ===== Gen loss: 2.5261
# Epoch: 976 ===== Batch: 0/235 ===== Disc loss: 0.6552 ===== Gen loss: 2.1578
# Epoch: 976 ===== Batch: 50/235 ===== Disc loss: 0.6526 ===== Gen loss: 2.5450
# Epoch: 976 ===== Batch: 100/235 ===== Disc loss: 0.6558 ===== Gen loss: 2.3488
# Epoch: 976 ===== Batch: 150/235 ===== Disc loss: 0.6532 ===== Gen loss: 2.3374
# Epoch: 976 ===== Batch: 200/235 ===== Disc loss: 0.6524 ===== Gen loss: 2.4032
# Epoch: 977 ===== Batch: 0/235 ===== Disc loss: 0.6586 ===== Gen loss: 2.1552
# Epoch: 977 ===== Batch: 50/235 ===== Disc loss: 0.6552 ===== Gen loss: 2.5577
# Epoch: 977 ===== Batch: 100/235 ===== Disc loss: 0.6615 ===== Gen loss: 2.3153
# Epoch: 977 ===== Batch: 150/235 ===== Disc loss: 0.6560 ===== Gen loss: 2.4122
# Epoch: 977 ===== Batch: 200/235 ===== Disc loss: 0.6573 ===== Gen loss: 2.2250
# Epoch: 978 ===== Batch: 0/235 ===== Disc loss: 0.6539 ===== Gen loss: 2.2945
# Epoch: 978 ===== Batch: 50/235 ===== Disc loss: 0.6554 ===== Gen loss: 2.1532
# Epoch: 978 ===== Batch: 100/235 ===== Disc loss: 0.6534 ===== Gen loss: 2.1914
# Epoch: 978 ===== Batch: 150/235 ===== Disc loss: 0.6548 ===== Gen loss: 2.4345
# Epoch: 978 ===== Batch: 200/235 ===== Disc loss: 0.6651 ===== Gen loss: 2.2017
# Epoch: 979 ===== Batch: 0/235 ===== Disc loss: 0.6559 ===== Gen loss: 2.2467
# Epoch: 979 ===== Batch: 50/235 ===== Disc loss: 0.6588 ===== Gen loss: 2.4050
# Epoch: 979 ===== Batch: 100/235 ===== Disc loss: 0.6555 ===== Gen loss: 2.3319
# Epoch: 979 ===== Batch: 150/235 ===== Disc loss: 0.6529 ===== Gen loss: 2.4143
# Epoch: 979 ===== Batch: 200/235 ===== Disc loss: 0.6533 ===== Gen loss: 2.4184
# Epoch: 980 ===== Batch: 0/235 ===== Disc loss: 0.6630 ===== Gen loss: 2.3708
# Epoch: 980 ===== Batch: 50/235 ===== Disc loss: 0.6525 ===== Gen loss: 2.3618
# Epoch: 980 ===== Batch: 100/235 ===== Disc loss: 0.6522 ===== Gen loss: 2.3370
# Epoch: 980 ===== Batch: 150/235 ===== Disc loss: 0.6557 ===== Gen loss: 2.3784
# Epoch: 980 ===== Batch: 200/235 ===== Disc loss: 0.6552 ===== Gen loss: 2.3604
# Epoch: 981 ===== Batch: 0/235 ===== Disc loss: 0.6598 ===== Gen loss: 2.2054
# Epoch: 981 ===== Batch: 50/235 ===== Disc loss: 0.6574 ===== Gen loss: 2.3998
# Epoch: 981 ===== Batch: 100/235 ===== Disc loss: 0.6518 ===== Gen loss: 2.3634
# Epoch: 981 ===== Batch: 150/235 ===== Disc loss: 0.6604 ===== Gen loss: 2.3698
# Epoch: 981 ===== Batch: 200/235 ===== Disc loss: 0.6586 ===== Gen loss: 2.4858
# Epoch: 982 ===== Batch: 0/235 ===== Disc loss: 0.6560 ===== Gen loss: 2.1662
# Epoch: 982 ===== Batch: 50/235 ===== Disc loss: 0.6539 ===== Gen loss: 2.3736
# Epoch: 982 ===== Batch: 100/235 ===== Disc loss: 0.6536 ===== Gen loss: 2.1639
# Epoch: 982 ===== Batch: 150/235 ===== Disc loss: 0.6533 ===== Gen loss: 2.2403
# Epoch: 982 ===== Batch: 200/235 ===== Disc loss: 0.6529 ===== Gen loss: 2.1998
# Epoch: 983 ===== Batch: 0/235 ===== Disc loss: 0.6532 ===== Gen loss: 2.2908
# Epoch: 983 ===== Batch: 50/235 ===== Disc loss: 0.6559 ===== Gen loss: 2.3203
# Epoch: 983 ===== Batch: 100/235 ===== Disc loss: 0.6550 ===== Gen loss: 2.3002
# Epoch: 983 ===== Batch: 150/235 ===== Disc loss: 0.6537 ===== Gen loss: 2.3368
# Epoch: 983 ===== Batch: 200/235 ===== Disc loss: 0.6520 ===== Gen loss: 2.2659
# Epoch: 984 ===== Batch: 0/235 ===== Disc loss: 0.6751 ===== Gen loss: 2.4979
# Epoch: 984 ===== Batch: 50/235 ===== Disc loss: 0.6517 ===== Gen loss: 2.2977
# Epoch: 984 ===== Batch: 100/235 ===== Disc loss: 0.6544 ===== Gen loss: 2.3161
# Epoch: 984 ===== Batch: 150/235 ===== Disc loss: 0.6547 ===== Gen loss: 2.3093
# Epoch: 984 ===== Batch: 200/235 ===== Disc loss: 0.6534 ===== Gen loss: 2.4022
# Epoch: 985 ===== Batch: 0/235 ===== Disc loss: 0.6519 ===== Gen loss: 2.2703
# Epoch: 985 ===== Batch: 50/235 ===== Disc loss: 0.6529 ===== Gen loss: 2.3299
# Epoch: 985 ===== Batch: 100/235 ===== Disc loss: 0.6557 ===== Gen loss: 2.3838
# Epoch: 985 ===== Batch: 150/235 ===== Disc loss: 0.6625 ===== Gen loss: 2.4823
# Epoch: 985 ===== Batch: 200/235 ===== Disc loss: 0.6545 ===== Gen loss: 2.4830
# Epoch: 986 ===== Batch: 0/235 ===== Disc loss: 0.6536 ===== Gen loss: 2.2799
# Epoch: 986 ===== Batch: 50/235 ===== Disc loss: 0.6549 ===== Gen loss: 2.4102
# Epoch: 986 ===== Batch: 100/235 ===== Disc loss: 0.6567 ===== Gen loss: 2.3965
# Epoch: 986 ===== Batch: 150/235 ===== Disc loss: 0.6579 ===== Gen loss: 2.6142
# Epoch: 986 ===== Batch: 200/235 ===== Disc loss: 0.6587 ===== Gen loss: 2.3582
# Epoch: 987 ===== Batch: 0/235 ===== Disc loss: 0.6685 ===== Gen loss: 2.6680
# Epoch: 987 ===== Batch: 50/235 ===== Disc loss: 0.6531 ===== Gen loss: 2.2794
# Epoch: 987 ===== Batch: 100/235 ===== Disc loss: 0.6515 ===== Gen loss: 2.2380
# Epoch: 987 ===== Batch: 150/235 ===== Disc loss: 0.6528 ===== Gen loss: 2.2969
# Epoch: 987 ===== Batch: 200/235 ===== Disc loss: 0.6577 ===== Gen loss: 2.5786
# Epoch: 988 ===== Batch: 0/235 ===== Disc loss: 0.6614 ===== Gen loss: 2.4167
# Epoch: 988 ===== Batch: 50/235 ===== Disc loss: 0.6539 ===== Gen loss: 2.1396
# Epoch: 988 ===== Batch: 100/235 ===== Disc loss: 0.6579 ===== Gen loss: 2.3135
# Epoch: 988 ===== Batch: 150/235 ===== Disc loss: 0.6546 ===== Gen loss: 2.3358
# Epoch: 988 ===== Batch: 200/235 ===== Disc loss: 0.6525 ===== Gen loss: 2.3203
# Epoch: 989 ===== Batch: 0/235 ===== Disc loss: 0.6539 ===== Gen loss: 2.4786
# Epoch: 989 ===== Batch: 50/235 ===== Disc loss: 0.6521 ===== Gen loss: 2.3431
# Epoch: 989 ===== Batch: 100/235 ===== Disc loss: 0.6543 ===== Gen loss: 2.3955
# Epoch: 989 ===== Batch: 150/235 ===== Disc loss: 0.6525 ===== Gen loss: 2.2914
# Epoch: 989 ===== Batch: 200/235 ===== Disc loss: 0.6519 ===== Gen loss: 2.2834
# Epoch: 990 ===== Batch: 0/235 ===== Disc loss: 0.6675 ===== Gen loss: 2.5568
# Epoch: 990 ===== Batch: 50/235 ===== Disc loss: 0.6650 ===== Gen loss: 2.6222
# Epoch: 990 ===== Batch: 100/235 ===== Disc loss: 0.6520 ===== Gen loss: 2.2179
# Epoch: 990 ===== Batch: 150/235 ===== Disc loss: 0.6549 ===== Gen loss: 2.1304
# Epoch: 990 ===== Batch: 200/235 ===== Disc loss: 0.6523 ===== Gen loss: 2.4213
# Epoch: 991 ===== Batch: 0/235 ===== Disc loss: 0.6703 ===== Gen loss: 2.0988
# Epoch: 991 ===== Batch: 50/235 ===== Disc loss: 0.6698 ===== Gen loss: 2.1943
# Epoch: 991 ===== Batch: 100/235 ===== Disc loss: 0.6517 ===== Gen loss: 2.3848
# Epoch: 991 ===== Batch: 150/235 ===== Disc loss: 0.6535 ===== Gen loss: 2.4805
# Epoch: 991 ===== Batch: 200/235 ===== Disc loss: 0.6568 ===== Gen loss: 2.4657
# Epoch: 992 ===== Batch: 0/235 ===== Disc loss: 0.6523 ===== Gen loss: 2.2269
# Epoch: 992 ===== Batch: 50/235 ===== Disc loss: 0.6591 ===== Gen loss: 2.0844
# Epoch: 992 ===== Batch: 100/235 ===== Disc loss: 0.6547 ===== Gen loss: 2.3955
# Epoch: 992 ===== Batch: 150/235 ===== Disc loss: 0.6516 ===== Gen loss: 2.3143
# Epoch: 992 ===== Batch: 200/235 ===== Disc loss: 0.6570 ===== Gen loss: 2.2488
# Epoch: 993 ===== Batch: 0/235 ===== Disc loss: 0.6545 ===== Gen loss: 2.3829
# Epoch: 993 ===== Batch: 50/235 ===== Disc loss: 0.6533 ===== Gen loss: 2.3816
# Epoch: 993 ===== Batch: 100/235 ===== Disc loss: 0.6599 ===== Gen loss: 2.6027
# Epoch: 993 ===== Batch: 150/235 ===== Disc loss: 0.6532 ===== Gen loss: 2.4492
# Epoch: 993 ===== Batch: 200/235 ===== Disc loss: 0.6529 ===== Gen loss: 2.4114
# Epoch: 994 ===== Batch: 0/235 ===== Disc loss: 0.6726 ===== Gen loss: 2.6077
# Epoch: 994 ===== Batch: 50/235 ===== Disc loss: 0.6563 ===== Gen loss: 2.4847
# Epoch: 994 ===== Batch: 100/235 ===== Disc loss: 0.6540 ===== Gen loss: 2.3736
# Epoch: 994 ===== Batch: 150/235 ===== Disc loss: 0.6526 ===== Gen loss: 2.3587
# Epoch: 994 ===== Batch: 200/235 ===== Disc loss: 0.6535 ===== Gen loss: 2.3674
# Epoch: 995 ===== Batch: 0/235 ===== Disc loss: 0.6535 ===== Gen loss: 2.3500
# Epoch: 995 ===== Batch: 50/235 ===== Disc loss: 0.6798 ===== Gen loss: 1.8478
# Epoch: 995 ===== Batch: 100/235 ===== Disc loss: 0.6556 ===== Gen loss: 2.4987
# Epoch: 995 ===== Batch: 150/235 ===== Disc loss: 0.6554 ===== Gen loss: 2.3609
# Epoch: 995 ===== Batch: 200/235 ===== Disc loss: 0.6578 ===== Gen loss: 2.0965
# Epoch: 996 ===== Batch: 0/235 ===== Disc loss: 0.6553 ===== Gen loss: 2.5622
# Epoch: 996 ===== Batch: 50/235 ===== Disc loss: 0.6528 ===== Gen loss: 2.3772
# Epoch: 996 ===== Batch: 100/235 ===== Disc loss: 0.6528 ===== Gen loss: 2.3124
# Epoch: 996 ===== Batch: 150/235 ===== Disc loss: 0.6530 ===== Gen loss: 2.3962
# Epoch: 996 ===== Batch: 200/235 ===== Disc loss: 0.6540 ===== Gen loss: 2.3152
# Epoch: 997 ===== Batch: 0/235 ===== Disc loss: 0.6545 ===== Gen loss: 2.3144
# Epoch: 997 ===== Batch: 50/235 ===== Disc loss: 0.6533 ===== Gen loss: 2.2928
# Epoch: 997 ===== Batch: 100/235 ===== Disc loss: 0.6555 ===== Gen loss: 2.3517
# Epoch: 997 ===== Batch: 150/235 ===== Disc loss: 0.6558 ===== Gen loss: 2.2268
# Epoch: 997 ===== Batch: 200/235 ===== Disc loss: 0.6520 ===== Gen loss: 2.2723
# Epoch: 998 ===== Batch: 0/235 ===== Disc loss: 0.6669 ===== Gen loss: 2.4523
# Epoch: 998 ===== Batch: 50/235 ===== Disc loss: 0.6535 ===== Gen loss: 2.4493
# Epoch: 998 ===== Batch: 100/235 ===== Disc loss: 0.6560 ===== Gen loss: 2.3720
# Epoch: 998 ===== Batch: 150/235 ===== Disc loss: 0.6558 ===== Gen loss: 2.5526
# Epoch: 998 ===== Batch: 200/235 ===== Disc loss: 0.6555 ===== Gen loss: 2.3636
# Epoch: 999 ===== Batch: 0/235 ===== Disc loss: 0.6526 ===== Gen loss: 2.3800
# Epoch: 999 ===== Batch: 50/235 ===== Disc loss: 0.6542 ===== Gen loss: 2.3824
# Epoch: 999 ===== Batch: 100/235 ===== Disc loss: 0.6523 ===== Gen loss: 2.3400
# Epoch: 999 ===== Batch: 150/235 ===== Disc loss: 0.6516 ===== Gen loss: 2.3307
# Epoch: 999 ===== Batch: 200/235 ===== Disc loss: 0.6524 ===== Gen loss: 2.2164

# %%
# dummy for initializing
step = 0
dataset = FashionMNIST(root="dataset/", train=True, transform=data_transforms, download=True)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
print("Start training...")

# loop over all epochs and all data
for epoch in range(EPOCHS):
    for batch_idx, (data, target) in enumerate(dataloader):
        # set the data to cuda
        data = data.to(device)

        # get the batch size 
        batch_size = data.shape[0]

        # Train the discriminator model on real data
        disc_model.zero_grad()
        label = (torch.ones(batch_size) * 0.9).to(device)
        output = disc_model(data).reshape(-1)
        real_disc_loss = criterion(output, label)
        d_x = output.mean().item()

        # train the disc model on fake (generated) data
        noise = torch.randn(batch_size, noise_channels, 1, 1).to(device)
        fake = gen_model(noise)
        label = (torch.ones(batch_size) * 0.1).to(device)
        output = disc_model(fake.detach()).reshape(-1)
        fake_disc_loss = criterion(output, label)

        # calculate the final discriminator loss
        disc_loss = real_disc_loss + fake_disc_loss

        # apply the optimizer and gradient
        disc_loss.backward()
        disc_optimizer.step()

        # train the generator model
        gen_model.zero_grad()
        label = torch.ones(batch_size).to(device)
        output = disc_model(fake).reshape(-1)
        gen_loss = criterion(output, label)
        # apply the optimizer and gradient
        gen_loss.backward()
        gen_optimizer.step()

        # print losses in console and tensorboard
        if batch_idx % 50 == 0:
            step += 1

            # print everything
            print(
                f"Epoch: {epoch} ===== Batch: {batch_idx}/{len(dataloader)} ===== Disc loss: {disc_loss:.4f} ===== Gen loss: {gen_loss:.4f}"
            )

            ### test the model
            with torch.no_grad():
                # generate fake images 
                fake_images = gen_model(fixed_noise)
                # make grid in the tensorboard
                img_grid_real = torchvision.utils.make_grid(data[:40], normalize=True)
                img_grid_fake = torchvision.utils.make_grid(fake_images[:40], normalize=True)

                # write the images in tensorbaord
                writer_real.add_image(
                    "Real images", img_grid_real, global_step=step
                )
                writer_fake.add_image(
                    "Generated images", img_grid_fake, global_step=step
                )

torch.save(gen_model.state_dict(), 'generator1.pth')
torch.save(disc_model.state_dict(), 'discriminator1.pth')
# Out:
# Start training...
# Epoch: 0 ===== Batch: 0/235 ===== Disc loss: 1.4964 ===== Gen loss: 2.1780
# Epoch: 0 ===== Batch: 50/235 ===== Disc loss: 0.8649 ===== Gen loss: 1.0421
# Epoch: 0 ===== Batch: 100/235 ===== Disc loss: 1.4154 ===== Gen loss: 0.7472
# Epoch: 0 ===== Batch: 150/235 ===== Disc loss: 1.2617 ===== Gen loss: 1.3516
# Epoch: 0 ===== Batch: 200/235 ===== Disc loss: 1.1988 ===== Gen loss: 1.1624

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir="C:\Users\onyx6\Project\runs"
# Out:
#       <iframe id="tensorboard-frame-169a2624791f120f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-169a2624791f120f");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import torch

# Instantiate the generator model
generator = Generator(noise_channels, image_channels, gen_features)

# Load the saved state dictionary
generator.load_state_dict(torch.load('generator.pth', map_location=torch.device('cpu')))  # Load onto CPU

# Move the generator model to the appropriate device (CPU or GPU)
generator.to(device)

# Set the generator model to evaluation mode
generator.eval()

# Generate fake images
with torch.no_grad():
    # Assuming fixed_noise is your fixed input noise tensor
    fixed_noise = torch.randn(batch_size, noise_channels, 1, 1).to(device)
    fake_images = generator(fixed_noise)

# Now fake_images contains the generated fake images
import matplotlib.pyplot as plt
import torchvision.utils

# Convert the fake images to a grid
fake_images_grid = torchvision.utils.make_grid(fake_images.cpu(), nrow=8, normalize=True)

# Convert the PyTorch tensor to a NumPy array and transpose the dimensions
fake_images_grid_np = fake_images_grid.permute(1, 2, 0).numpy()

# Display the fake images grid using matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(fake_images_grid_np)
plt.axis('off')
plt.show()
